# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Dataset-exploration" data-toc-modified-id="Dataset-exploration-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Dataset exploration</a></span><ul class="toc-item"><li><span><a href="#Content-of-the-files" data-toc-modified-id="Content-of-the-files-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Content of the files</a></span></li><li><span><a href="#Importing-the-data" data-toc-modified-id="Importing-the-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Importing the data</a></span></li></ul></li><li><span><a href="#Detecting-similar-books" data-toc-modified-id="Detecting-similar-books-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Detecting similar books</a></span><ul class="toc-item"><li><span><a href="#Using-titles-to-obtain-candidate-similars" data-toc-modified-id="Using-titles-to-obtain-candidate-similars-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Using titles to obtain candidate similars</a></span><ul class="toc-item"><li><span><a href="#Local-Sensitivity-Hashing" data-toc-modified-id="Local-Sensitivity-Hashing-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Local Sensitivity Hashing</a></span><ul class="toc-item"><li><span><a href="#The-minhash" data-toc-modified-id="The-minhash-3.1.1.1"><span class="toc-item-num">3.1.1.1&nbsp;&nbsp;</span>The <code>minhash</code></a></span></li><li><span><a href="#The-principle-of-LSH" data-toc-modified-id="The-principle-of-LSH-3.1.1.2"><span class="toc-item-num">3.1.1.2&nbsp;&nbsp;</span>The principle of LSH</a></span></li></ul></li><li><span><a href="#Using-LSH-to-work-on-titles" data-toc-modified-id="Using-LSH-to-work-on-titles-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Using LSH to work on titles</a></span></li><li><span><a href="#Inspecting-the-result-of-LSH-on-books-titles" data-toc-modified-id="Inspecting-the-result-of-LSH-on-books-titles-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Inspecting the result of LSH on books titles</a></span></li></ul></li><li><span><a href="#Enriching-our-dataset-using-Amazon-product-Advertising-API" data-toc-modified-id="Enriching-our-dataset-using-Amazon-product-Advertising-API-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Enriching our dataset using Amazon product Advertising API</a></span></li><li><span><a href="#Using-author-list-to-refine-candidate-similars" data-toc-modified-id="Using-author-list-to-refine-candidate-similars-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Using author list to refine candidate similars</a></span></li><li><span><a href="#Using-titles-to-obtain-our-final-set-of-similar-books" data-toc-modified-id="Using-titles-to-obtain-our-final-set-of-similar-books-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Using titles to obtain our final set of similar books</a></span></li><li><span><a href="#Saving-the-data-using-pickle-for-further-analysis" data-toc-modified-id="Saving-the-data-using-pickle-for-further-analysis-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Saving the data using pickle for further analysis</a></span></li><li><span><a href="#Finding-examples-for-the-data-story" data-toc-modified-id="Finding-examples-for-the-data-story-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Finding examples for the data-story</a></span><ul class="toc-item"><li><span><a href="#Too-many-books-to-compare-them-one-to-one" data-toc-modified-id="Too-many-books-to-compare-them-one-to-one-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Too many books to compare them one to one</a></span></li><li><span><a href="#Using-the-power-of-Hashing" data-toc-modified-id="Using-the-power-of-Hashing-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Using the power of Hashing</a></span></li><li><span><a href="#From-candidates-similar-to-similars" data-toc-modified-id="From-candidates-similar-to-similars-3.6.3"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>From candidates similar to similars</a></span><ul class="toc-item"><li><span><a href="#An-example-from-the-first-filter" data-toc-modified-id="An-example-from-the-first-filter-3.6.3.1"><span class="toc-item-num">3.6.3.1&nbsp;&nbsp;</span>An example from the first filter</a></span></li><li><span><a href="#An-example-from-the-second-filter" data-toc-modified-id="An-example-from-the-second-filter-3.6.3.2"><span class="toc-item-num">3.6.3.2&nbsp;&nbsp;</span>An example from the second filter</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Correlation-analysis" data-toc-modified-id="Correlation-analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Correlation analysis</a></span><ul class="toc-item"><li><span><a href="#Reviews-analysis" data-toc-modified-id="Reviews-analysis-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Reviews analysis</a></span><ul class="toc-item"><li><span><a href="#Reviews-distribution" data-toc-modified-id="Reviews-distribution-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Reviews distribution</a></span></li><li><span><a href="#Evolution-of-reviews-over-time" data-toc-modified-id="Evolution-of-reviews-over-time-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Evolution of reviews over time</a></span></li></ul></li><li><span><a href="#How-reviews-influence-the-sales-rank" data-toc-modified-id="How-reviews-influence-the-sales-rank-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>How reviews influence the sales rank</a></span><ul class="toc-item"><li><span><a href="#On-the-books-in-the-similar-dataset" data-toc-modified-id="On-the-books-in-the-similar-dataset-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>On the books in the similar dataset</a></span></li><li><span><a href="#Modifying-the-ranks" data-toc-modified-id="Modifying-the-ranks-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Modifying the ranks</a></span><ul class="toc-item"><li><span><a href="#Obtaining-a-continuous-sales-rank" data-toc-modified-id="Obtaining-a-continuous-sales-rank-4.2.2.1"><span class="toc-item-num">4.2.2.1&nbsp;&nbsp;</span>Obtaining a continuous sales rank</a></span></li><li><span><a href="#Deducing-a-rank-from-the-review-average" data-toc-modified-id="Deducing-a-rank-from-the-review-average-4.2.2.2"><span class="toc-item-num">4.2.2.2&nbsp;&nbsp;</span>Deducing a rank from the review average</a></span></li><li><span><a href="#Considering-books-with-sufficient-number-of-reviews" data-toc-modified-id="Considering-books-with-sufficient-number-of-reviews-4.2.2.3"><span class="toc-item-num">4.2.2.3&nbsp;&nbsp;</span>Considering books with sufficient number of reviews</a></span></li></ul></li><li><span><a href="#Comparison-of-books-that-are-similar" data-toc-modified-id="Comparison-of-books-that-are-similar-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Comparison of books that are similar</a></span></li></ul></li><li><span><a href="#How-reviews-influence-the-price" data-toc-modified-id="How-reviews-influence-the-price-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>How reviews influence the price</a></span><ul class="toc-item"><li><span><a href="#Comparison-of-books-together" data-toc-modified-id="Comparison-of-books-together-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Comparison of books together</a></span></li></ul></li></ul></li><li><span><a href="#Herding-Effect-analysis" data-toc-modified-id="Herding-Effect-analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Herding Effect analysis</a></span><ul class="toc-item"><li><span><a href="#Pre-analysis" data-toc-modified-id="Pre-analysis-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Pre-analysis</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#H/M/L-Categorization" data-toc-modified-id="H/M/L-Categorization-5.1.0.1"><span class="toc-item-num">5.1.0.1&nbsp;&nbsp;</span>H/M/L Categorization</a></span></li></ul></li><li><span><a href="#Herding-Effect-Analysis" data-toc-modified-id="Herding-Effect-Analysis-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Herding Effect Analysis</a></span><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-5.1.1.1"><span class="toc-item-num">5.1.1.1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#A-first-example" data-toc-modified-id="A-first-example-5.1.1.2"><span class="toc-item-num">5.1.1.2&nbsp;&nbsp;</span>A first example</a></span></li><li><span><a href="#Generalization" data-toc-modified-id="Generalization-5.1.1.3"><span class="toc-item-num">5.1.1.3&nbsp;&nbsp;</span>Generalization</a></span></li><li><span><a href="#Deeper-Analysis-of-the-left-over-categories-from-MS2-analysis" data-toc-modified-id="Deeper-Analysis-of-the-left-over-categories-from-MS2-analysis-5.1.1.4"><span class="toc-item-num">5.1.1.4&nbsp;&nbsp;</span>Deeper Analysis of the left over categories from MS2 analysis</a></span></li><li><span><a href="#confirmation-of-the-herding-effect-on-MM-and-LL" data-toc-modified-id="confirmation-of-the-herding-effect-on-MM-and-LL-5.1.1.5"><span class="toc-item-num">5.1.1.5&nbsp;&nbsp;</span>confirmation of the herding effect on MM and LL</a></span></li><li><span><a href="#confirmation-of-a-smaller-herding-effect-on-HM-and-ML" data-toc-modified-id="confirmation-of-a-smaller-herding-effect-on-HM-and-ML-5.1.1.6"><span class="toc-item-num">5.1.1.6&nbsp;&nbsp;</span>confirmation of a smaller herding effect on HM and ML</a></span></li><li><span><a href="#long-term-effect-of-herding-on-the-scaled-dataset" data-toc-modified-id="long-term-effect-of-herding-on-the-scaled-dataset-5.1.1.7"><span class="toc-item-num">5.1.1.7&nbsp;&nbsp;</span>long term effect of herding on the scaled dataset</a></span></li><li><span><a href="#Limitation-of-this-analysis" data-toc-modified-id="Limitation-of-this-analysis-5.1.1.8"><span class="toc-item-num">5.1.1.8&nbsp;&nbsp;</span>Limitation of this analysis</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Connection-to-how-amazon-displays-reviews" data-toc-modified-id="Connection-to-how-amazon-displays-reviews-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Connection to how amazon displays reviews</a></span><ul class="toc-item"><li><span><a href="#Computation-of-average-grading" data-toc-modified-id="Computation-of-average-grading-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Computation of average grading</a></span></li><li><span><a href="#Incentivized-reviews" data-toc-modified-id="Incentivized-reviews-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Incentivized reviews</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li></ul></div>

# %%
# %matplotlib inline
# To reload external scripts automatically
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import sys
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
import os
from itertools import combinations

# Importing external files
from scripts.similarities import *
from scripts.amazon_api_interaction import *
from scripts.analysis import *
from scripts.data_import import *
from scripts.utils_project import *

pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.

# %% [markdown]
# In this notebook, we have tried to depict the full pipeline that we used for this project. It will not mention all the research that was done initially on a smaller dataset but those can be found in the ```research.ipynb```. Also note that most of the methods we use have been externalized to python files that can be found in ```scripts```.

# %% [markdown]
# # Introduction
#
# _The goal of this project is to study the effect of the first review on an amazon product to subsequent reviews. This is also called the Herding effect._

# %% [markdown]
# Before we get started we wanted to explain our strategy. We have decided to focus on Amazon books as those make a great product to study the Herding effect as they are often available in different edition which do not modify the content.
# 1. The most challenging part was to **Identify similar books**. Indeed with a very large number of books it was complex to use pair wise comparison to do such task. Therefore we used Locality sensitive Hashing on the titles of the books (you can refer to the section for further explanations).
#     * This method yields bins of candidate similar books that needs further refinements. While we first wanted to use the description of the book to find for example authors and other information, it turns out that most description are simply comments from journalists on the book and is therefore not that helpful. We decided to use **Amazon product advertising API** to obtain more metadata on the books that we found to be candidate similars.
#     * Then **we used the authors of each book to refine candidate similars** where we tried to match the list of authors between two candidates by matching each author in a list to the author in the second book that had the least Levenstein distance. Once this matching was realized we look at the mean distance (the levenstein distance was transformed into a relative value to allow the comparison) and we consider valid two books whose mean relative levenstein distance is lower than 0.35. This phase allowed to delete books that had similar titles but not at all similar authors.
#     * Finally we cleaned the titles from any unnecessary characters (parenthesis, colon, all lower case etc.) and decided to match two books if and only if the **symmetric difference of their normalized titles** is empty (which means that one of the set is entirely contained in the other).
# 2. Once we had those similar books, the real analysis can start. First of all we wanted to study the impact of reviews on the way user shop on the website (by using several metrics, trying for example to see the impact of average rating on the sales rank)
# 3. The very last step consisted in showing the Herding effect:
#     * **Pre-analysis** of the obtained dataset was necessary in order to categorize the books into 6 categories (```HH,HM,HL,MM,ML,LL```) where ```H``` means that the first review of a book is High, ```M``` means that it is medium and ```L``` it is low. (you can refer to the section itself to see how we mapped those categories to the number of stars a book had)
#     * We then plotted the average ratings for each groups depending on the fact that the book belong to the first or second letter of its category in order to see the **influence of the first review on the following**. Because of a quick convergence toward a similar value, we only analyzed the effect on the 5 first reviews.
#     * As a final step we wanted to show the review average for each group on a **long term basis**. That is we wanted to see if on average the same book that had a first ```L``` rating has a lower review average in the long term than when it had a ```H``` first rating (comparing ```H``` in ```HL``` and ```L``` in ```HL```)

# %%
DATA_FOLDER = "../../Project-Data-corrected/"
META_FOLDER = DATA_FOLDER + "meta/"
REVIEWS_FOLDER = DATA_FOLDER + "reviews/"
CORE_FOLDER = DATA_FOLDER + "5_core/"
DUMP_FOLDER = DATA_FOLDER + "dump/"
CATEGORIES = ['Books','Movies_and_Tv','Electronics']
MAXCOUNT = -1
ANALYSIS_DATA_FOLDER = 'analysis_data/'

# %% [markdown]
# # Dataset exploration

# %% [markdown]
# ## Content of the files

# %% [markdown]
# Because we have a lot of data we decided to first look at the content of the dataset in order to import into dataframes only the metadata that can be useful for our study. Note that we have three different types of file: **metadata**, **reviews** and **5-core** (which contains only reviews on products and reviewers that have at least 5 reviews).

# %% [markdown]
# The different columns of the **metadata** files are :
# * ```asin``` : the unique identifier of the object
# * ```brand```
# * ```categories``` : the categories of the object
# * ```description``` : the description of the object
# * ```imUrl```  : the link toward the images related to the object
# * ```price```
# * ```related``` : a list of objects that are related to this object
# * ```salesRank```
# * ```title```
#
# The different columns of the **reviews** and **5-core** files are :
# * ```asin``` : the unique identifier of the object
# * ```helpful``` : a list of 2 integers [x,y], the helpfulness score is x/y votes
# * ```overall``` : the rating of the object
# * ```reviewText```
# * ```reviewTime```
# * ```reviewerID```
# * ```reviewerName```
# * ```summary ``` : the title of the review
# * ```unixReviewTime``` : in Unix format
#
# Therefore we keep only the column that are of interest for our task

# %%
meta_interesting_cols = ['asin', 'title', 'salesRank', 'description','imUrl']
review_interesting_cols = ['asin', 'overall', 'unixReviewTime']

# %% [markdown]
# ## Importing the data

# %% [markdown]
# Working with large JSON would add a layer of complexity and therefore we imported the files to dataframes. A full pipeline has been made to do so. (NB: even-though the 5 core data was used for the exploratory phase we do not use it in the final study)

# %%
meta_books_path, review_books_path, core_book_path = get_paths(
    0, DATA_FOLDER, META_FOLDER, CORE_FOLDER, REVIEWS_FOLDER, CATEGORIES)
meta_books = import_interesting_cols(
    meta_books_path,
    DUMP_FOLDER,
    True,
    meta_interesting_cols,
    max_count=MAXCOUNT)
review_books = import_interesting_cols(
    review_books_path,
    DUMP_FOLDER,
    False,
    review_interesting_cols,
    max_count=MAXCOUNT)
# Out:
# Paths :
# 	 meta = ../../Project-Data-corrected/meta/meta_Books.json
# 	 review = ../../Project-Data-corrected/reviews/reviews_Books.json
# 	 core_path = ../../Project-Data-corrected/5_core/Books.json
# Retrieving from : ../../Project-Data-corrected/dump/meta_Books_asin_title_salesRank_description_imUrl_ALL
# It took 00:00:04.607 to import the data.
# Retrieving from : ../../Project-Data-corrected/dump/reviews_Books_asin_overall_unixReviewTime_ALL
# It took 00:00:01.907 to import the data.

# %%
print("The meta_books dataframe has {} books and {} attributes".format(meta_books.shape[0],meta_books.shape[1]))
meta_books.head(1)
# Out:
# The meta_books dataframe has 2370585 books and 21 attributes
#          asin description                                              imUrl  \
# 0  0001048791         NaN  http://ecx.images-amazon.com/images/I/51MKP0T4...
#
#    salesRank_Arts,_Crafts_&_Sewing  salesRank_Books  \
# 0                              NaN        6334800.0
#
#    salesRank_Cell_Phones_&_Accessories  salesRank_Clothing  \
# 0                                  NaN                 NaN
#
#    salesRank_Electronics  salesRank_Health_&_Personal_Care  \
# 0                    NaN                               NaN
#
#    salesRank_Home_&_Kitchen  \
# 0                       NaN
#
#                          ...                          salesRank_Jewelry  \
# 0                        ...                                        NaN
#
#    salesRank_Kitchen_&_Dining  salesRank_Movies_&_TV  salesRank_Music  \
# 0                         NaN                    NaN              NaN
#
#    salesRank_Musical_Instruments  salesRank_Office_Products  salesRank_Shoes  \
# 0                            NaN                        NaN              NaN
#
#    salesRank_Sports_&_Outdoors  salesRank_Toys_&_Games  \
# 0                          NaN                     NaN
#
#                                                title
# 0  The Crucible: Performed by Stuart Pankin, Jero...
#
# [1 rows x 21 columns]

# %%
print("The review_books dataframe has {} reviews and {} attributes".format(review_books.shape[0],review_books.shape[1]))
review_books.head(1)
# Out:
# The review_books dataframe has 22507155 reviews and 3 attributes
#          asin  overall unixReviewTime
# 0  0000000116      4.0     2002-04-27

# %% [markdown]
# # Detecting similar books

# %% [markdown]
# We will now start to detect similar books. We have in previous exploratory discarded reviewers with less than 5 reviews and books with less than 5 reviews. While this latter does make sense for the Herding Effect analysis, the restriction on reviewers doesn't make much sense. We will therefore still keep the restriction on books of having at least 5 reviews.

# %%
print("In the full dataset we have {} books and  {} reviews".format(meta_books.shape[0],review_books.shape[0]))
books_reviews_count = review_books.groupby('asin').count().overall
asin_enough_reviews = list(books_reviews_count[books_reviews_count > 5].index)
print("We found {} books with enough reviews.".format(len(asin_enough_reviews)))
# Out:
# In the full dataset we have 2370585 books and  22507155 reviews
# We found 625682 books with enough reviews.

# %% [markdown]
# Now that we have obtained the identifiers of the books with enough reviews we will keep only those in the ```meta_books``` dataframe.

# %%
meta_books_reduced = meta_books[meta_books['asin'].isin(asin_enough_reviews)]
print("Now the books dataset is composed of {} books".format(meta_books_reduced.shape[0]))
# Out:
# Now the books dataset is composed of 625682 books

# %% [markdown]
# Since we are working on large datasets we took the habit to serialize our intermediate work to reduce the running time of the code. We will serialize those in the ```../../Project-Data/dump_full/``` folder (you can refer to the ```README``` to observe the file architecture of the project).

# %%
DUMP_FOLDER_FULL = DATA_FOLDER + 'dump_full/'

# %% [markdown]
# ## Using titles to obtain candidate similars

# %% [markdown]
# We will explain quickly how LSH works

# %% [markdown]
# ### Local Sensitivity Hashing

# %% [markdown]
# Based on this [article](http://dataconomy.com/2017/06/locality-sensitive-hashing-pydata/), and following the theory that can be read at the chapter 3.4 of [Mining of massive datasets by Leskovec, Rajaraman and Milliway](http://infolab.stanford.edu/~ullman/mmds/book.pdf) we will try to find similar books.

# %% [markdown]
# #### The ```minhash```

# %% [markdown]
# We need to detect near similar books in this large datasets. To do so we would need to compare each of the attribute of a given book with all the others which is extremely computationaly expensive. There we will use LSH. Right now the title and description of the book have variable length depending on the books. To perform LSH we would like to have a fixed length representation of the document without modifying the semantics of document similarity.
# * first we introduce the principle of shingles. A shingle of 5-gram (hence we discard the last shingle as it only consists in the $<5$ last characters of the document) e.g. is a set of all possible 5-grams in the string.

# %%
document = "Lorem Ipsum dolor sit amet"
shingles = get_shingles(document)
other_document = 'Lorem Ipsum dolor sit amet with some extra garbage'
other_shingles = get_shingles(other_document)
jaccard_dist(shingles,other_shingles)
# Out:
# 0.4666666666666667

# %% [markdown]
# Each document will still have a different number of shingles depending on its length. Therefore we wish to represent it using a *fixed length representation*. We will present now a function ```minhash``` that has a collision probability that is exactly the jaccard similarity (based on this [document](http://infolab.stanford.edu/~ullman/mmds/ch3.pdf) and following this [repo](https://github.com/mattilyra/LSH/blob/master/examples/Introduction.ipynb)) . We explain this now :
# 1. Suppose that the following dataframe is the boolean variable corresponding to whether or not a shingle belongs to a document
# 2. the ```minhash``` of a document returns a random permutation of the rows and then the first row number it founds where the value is non 0.
#     * therefore row 1 for doc 1
#     * and row 0 for doc 2

# %%
ex_minhash = pd.DataFrame({'shingleID':[1,2,3,4,5,6],'doc1':[0,1,0,0,1,1],'doc2':[1,1,1,0,1,0]})
ex_minhash
# Out:
#    doc1  doc2  shingleID
# 0     0     1          1
# 1     1     1          2
# 2     0     1          3
# 3     0     0          4
# 4     1     1          5
# 5     1     0          6

# %% [markdown]
# But this is for this particular permutation, if we had another one like below then the ```minhash``` would return :
#    * row 2 for doc1
#    * row 1 for doc2
#
# There are a lot of such permutations. Nevertheless we only care about having the same row for each document which mean we have collision of the ```minhash```. Therefore we have only two rows for which this happens : $\text{shingleID} \in \{2,5\}$. Hence the probability that the two doc have the same ```minhash``` (remmember that rows with two zeros do not count as they are not considered by ```minhash```) is the number of rows where both doc value is 1 divided by the number of rows where they are different : $\frac{2}{5}$

# %%
ex_minhash.sample(frac=1)
# Out:
#    doc1  doc2  shingleID
# 0     0     1          1
# 5     1     0          6
# 4     1     1          5
# 1     1     1          2
# 2     0     1          3
# 3     0     0          4

# %% [markdown]
# We can chose the length of the fingerprint that is returned by the ```minhash```, as we increase the length we get less variance from the random initialisation of the ```minhasher``` but this also greatly increases the memory usage.

# %% [markdown]
# #### The principle of LSH

# %%
from lsh import minhash
hasher = minhash.MinHasher(seeds=100, char_ngram=5)
fingerprint0 = hasher.fingerprint('Lorem Ipsum dolor sit amet'.encode('utf8'))
len(fingerprint0)
# Out:
# 100

# %% [markdown]
# Therefore the hash of a document is composed of a given (```seeds```) number of ```minhashes```. We divide this number of ```minhashes``` into a given number of parts (e.g. 5). Since every single ```minhash``` has the jaccard similarity probability of collision then each of the 5 parts will have this probability as well. These parts represent the **locality** in the term LSH.
#
# Then we hash the content of each part using a different hash function to obtain the *binID* that represents the **hashing** part of the method. Into each bin with *binID* we store the entire fingerprint of the document.
#
# The idea is then that we compare documents that fall in the same bins : we will compare their fingerprint which is equivalent to looking at their Jaccard similarity between shingle sets. Since not all documents will fall into the same bins we have reduced the number of potential candidates.
#
# Indeed we call :
# * ```seeds``` :  number of ```minihashes``` that compose the fingerprint
# * ```bands``` : the number of bins that we want to use

# %% [markdown]
# ### Using LSH to work on titles

# %% [markdown]
# Using LSH (local sensitivity hashing) we will now try to find bins of candidate similars using the tiltes of the amazon products. Therefore we will keep in our dataframe only the books with an existing title and only the columns that can later be of interest.

# %%
meta_books_reduced  = meta_books_reduced [meta_books_reduced ['title'].notnull()]
meta_books_reduced = meta_books_reduced[['asin','title','description','imUrl']]
meta_books_reduced.head()
# Out:
#           asin                                              title  \
# 10  0000913154  The Way Things Work: An Illustrated Encycloped...
# 13  0001055178                                     Master Georgie
# 25  0001018043                                The Enchanted Horse
# 34  0001473727  The Greatest Book on "Dispensational Truth" in...
# 37  0000230022  The Simple Truths of Service: Inspired by John...
#
#                                           description  \
# 10                                                NaN
# 13  Beryl Bainbridge seems drawn to disaster. Firs...
# 25  Grade 3-6-In this fast-paced fantasy, a neglec...
# 34                                                NaN
# 37                                                NaN
#
#                                                 imUrl
# 10  http://ecx.images-amazon.com/images/I/7113akhD...
# 13  http://ecx.images-amazon.com/images/I/51ZSC6TK...
# 25                                                NaN
# 34  http://ecx.images-amazon.com/images/I/512M299K...
# 37  http://ecx.images-amazon.com/images/I/218uMkP0...

# %%
dump_path = DUMP_FOLDER_FULL
get_candidate_full,asin_2_similarity_list = candidate_duplicates(meta_books_reduced,dump_path,['title'])
# Out:
# Retrieving from :
# 	../../Project-Data-corrected/dump_full/candidate_dup_title_2_100_5_4
#
# Found 14524 bins of possible duplicates.
# With 35871 different books
# It took 00:00:00.077 to import the data.

# %% [markdown]
# *NB: the hashing used involves random number and therefore different run of the method ```candidate_duplicates``` might result in slightly different bins. This is one of the reason why we also serialize the candidates in order to always have the same data to deduct conclusion in further work*

# %% [markdown]
# ### Inspecting the result of LSH on books titles

# %%
#Let's quickly oberve the type of data that we obtain
element_to_inspect = 2
similarity_keys = list(get_candidate_full.keys())
asins = get_candidate_full[similarity_keys[element_to_inspect]]
print_details(asins,meta_books_reduced,interesting_cols=['title','description'])
display_images(asins,meta_books_reduced)
# Out:
# Book 1852425849 - title: Whatever
# Book 0763628867 - title: Whatever
#
# Book 1852425849 - description: The unnamed narrator of Houellebecq's novel is Marcuse's one-dimensional man. A single, 30-year-old computer engineer in Paris with no sex life, he suffers from a chronic passivity that, in Houellebecq's view, is characteristic of Generation X. He buys, but doesn't take joy in any of the things he possesses. He has acquaintances, but no friends. In his off hours he writes dialogues featuring an assortment of barnyard animals. When his company sends him and a colleague, Bernard, out to Rouen and La Roche-sur-Yon to consult on software, nothing much gets done. In Rouen he suffers from heart problems. Since Bernard visits him in the hospital, a bond develops between them. Bernard, cursed with a repulsive appearance and a horny disposition, makes obnoxious advances to every woman he sees and is predictably rejected. Sexual deprivation is the atmosphere in which these men exist. That both men see women only in terms of their sexual features makes their impotence even more pathetic. After breaking up with his last girlfriend two years ago, the narrator has withdrawn from the romantic arena. And yet he has developed an intricate and mean-spirited, if ill-defined, theory of sexual hierarchy. The loose narrative condenses to an action sequence when the narrator tries to get Bernard to murder a woman with a steak knife, but the incident is gratuitous. In the end, Houellebecq displays none of the novelist's eye for detail and, further, defaults on the development of a vital main character, who might have connected this series of threadbare incidents into an interesting social comment. (Jan.) FYI: A bestseller in France, this novel won the 1995 Prix Flore for best first novel.Copyright 1998 Reed Business Information, Inc.
# Book 0763628867 - description: Kindergarten-Grade 2–A cautionary tale with spare text and striking graphics. Billy can be very difficult to please. Indifferent to his father's attempts to engage or impress him, the child responds to each try with an unenthusiastic …whatever. Dad plays the world's curliest trumpet, bounces Billy off the bounciest castle, and even takes him on a trip to the edge of outer space. Yet each effort fails to garner more than the same bored reaction. After the world's hungriest tiger fails to scare the impassive youngster, the animal swallows Billy whole. Dad! I am still in here you know.... In a fitting turnabout comes Dad's reply, …whatever. Bold, digitally created illustrations on stark white pages (except for outer space, which is on blue) engage the audience and mirror the humor in this slightly callous story that is reminiscent of Maurice Sendak'sPierre(HarperCollins, 1962). Children will enjoy the scrolls and curves of the curliest trumpet and the ridiculous image of Billy being bounced out of the bounciest castle, and recognize that the large, orange tiger is a creature to be reckoned with, even if the unconcerned Billy does not. Children will take pleasure in the book and get a laugh as well.–Piper L. Nyman, formerly at Fairfield Civic Center Library, CACopyright © Reed Business Information, a division of Reed Elsevier Inc. All rights reserved.
# <img src="http://ecx.images-amazon.com/images/I/519VftNaJBL.jpg" width="250" height="500"/>
# <img src="http://ecx.images-amazon.com/images/I/410WD692PCL.jpg" width="250" height="500"/>

# %% [markdown]
# We can see that the books can greatly vary even though they have the same title. Also it seems hard to extract any meaningful data from their description therefore we need to use the Amazon API to try to get the data we are looking for.

# %% [markdown]
# ## Enriching our dataset using Amazon product Advertising API

# %% [markdown]
# Because amazon API has strong limitations on the number of requests per account and the number of queries per seconds, we try to use it as efficiently as possible:
# * we decided to limit our QPS (query per second) to 0.9 as the limit is 1 QPS.
# * whenever the API throttles our queries we wait a random amount of time before retrying (following a random variable with exponential distribution of parameter 0.1, as advised by Amazon).
# * each query retrieves 10 books' details at a time.
#
# This will allow us to get many more details of our books : ```authors, publisher, ISBN, sales_rank_updated, binding, edition, release_date```. We might not need all of them but because of the restriction of the API we decided to obtain as much as possible for each book should we decide to use it later on.

# %%
amazon_access_file_path = DUMP_FOLDER + "amazon_access_epfl_new"
book_only_candidates,failed = fill_in_with_details(meta_books_reduced,amazon_access_file_path,get_candidate_full,asin_2_similarity_list,DUMP_FOLDER_FULL)
book_only_candidates.head(2)
# Out:
# Retrieving from :
# 	../../Project-Data-corrected/dump_full/book_only_candidates_with_details
# 	../../Project-Data-corrected/dump_full/api_failed
# It took 00:00:00.739 to get the data.
#          asin                                              title description  \
# 0  0001473727  The Greatest Book on "Dispensational Truth" in...         NaN
# 1  0001472933                                 The Book of Daniel         NaN
#
#                                                imUrl      authors  \
# 0  http://ecx.images-amazon.com/images/I/512M299K...  [C. Larkin]
# 1  http://ecx.images-amazon.com/images/I/414KH1FP...           []
#
#                                           publisher        ISBN  \
# 0  Titles distributed by Christian Art Distributors  0001473727
# 1                        Rev Clarence Larkin Estate  0001472933
#
#   sales_rank_updated binding edition release_date
# 0             837246   Relié    None         None
# 1            1569511   Relié    None         None

# %% [markdown]
# Some book ASIN might not have been successfully retrieved for numerous reasons, one of which might be that the object isn't sold anymore. We saved such failed ASIN in the ```failed``` list.

# %%
print("book_only_candidates.shape = ",book_only_candidates.shape)
print("{} have failed".format(len(failed)))
# Out:
# book_only_candidates.shape =  (35871, 11)
# 607 have failed

# %% [markdown]
# ## Using author list to refine candidate similars

# %% [markdown]
# Because the matching will now use authors of each books, we will eliminate from our dataset the books for which no authors was found (in the case where the API couldn't retrieve the details of the book using the ASIN) but also in the case where it is an empty list (the API call was successful but no author was returned.

# %% [markdown]
# We saw examples where the authors list between two books were very similar but names were written differently, therefore we need to check that some typos are not in the names of authors : (e.g. ```{'Ian MacNeill', 'SportMed BC'}{'Ian MacNeil'}``` where MacNeil is written with two 'l' in the first book but only one in the second one). Therefore we will first clean the names (remove accents, nomalize it to lower case) and then try to match then using the Levenstein distance, we match two author list if the mean difference between authors is less that 0.35 (NB: this is a relative distance in order to be able to compare title with different length).
#
# See the function ```check_name_similarity``` in the ```utils.py``` files for more details on how this is done.

# %%
similars,lsh_to_author = get_similar_authors(book_only_candidates,get_candidate_full,asin_2_similarity_list)
print("We have found {} bins of candidate similars".format(len(similars.keys())))
# Out:
# We have found 5880 bins of candidate similars

# %% [markdown]
# We can see that we have some unwanted behaviour of the author matching function. Indeed because we want to avoid at all cost false positives we have some matching that could trivially be done by humans : 'sir arthur conan doyle' and 'a conan doyle' are considered but should be considered similar. We decided to leave the task of refining the matching to a later study and possibly to a reader that would like to extend our work.

# %% [markdown]
# ## Using titles to obtain our final set of similar books

# %% [markdown]
# Now we might still have problems with books that have highly similar titles and authors but aren't identical. This could be explained by :
# * Different Tomes : same title but different number
# * educational books that have identical titles except for what they teach
# * simply typos or very small differences
# * many other examples
#
# Example of books that are not similar:
# ```
# Adobe Dreamweaver CS3 Classroom in a Book['adobe creative team']
# Adobe Dreamweaver CS4 Classroom in a Book['adobe creative team']
# Adobe Dreamweaver CS5 Classroom in a Book['adobe creative team']
# Adobe Dreamweaver CS6 Classroom in a Book['adobe creative team']
# ----------------------------------------------------------------
# Promethea, Book 3['alan moore']
# Promethea, Book 5['alan moore']
# Promethea, Book 1['alan moore', 'j. h. williams', 'mick gray']
#
# ```
#
# Example of books that should be considered similar:
# ```
# 'Light Science and Magic: An Introduction to Photographic Lighting'['fil hunter', 'paul fuqua', 'steven biver']
# 'Light: Science and Magic: An Introduction to Photographic Lighting'['fil hunter', 'steven biver', 'paul fuqua']
# ```
#
# We will therefore also need to see if the title are similar enough. **We want to avoid false positive as much as possible. We are sure that we could go even further with matching names but prefer to be conservative here**. Therefore we only try to normalize as much as possible the titles and see if then the titles taken as sets have an empty symmetric difference.

# %%
very_similars,authors_to_title = get_similar_titles(book_only_candidates,similars)
print("We have found {} bins of very similar books.".format(len(very_similars.keys())))
# Out:
# We have found 3173 bins of very similar books.

# %%
very_similar_ASIN = [item for sublist in list(very_similars.values()) for item in sublist]
print("We have {} asins for products that have at least one similar product.".format(len(very_similar_ASIN)))
# Out:
# We have 6711 asins for products that have at least one similar product.

# %% [markdown]
# Using the ```observational_print``` argument of ```get_similar_titles``` one can observe how our function is quite conservative and why:
#
# An example where the titles were not matched, providing there difference:
# ```
# 'college mathematics for business economics life sciences and social sciences 12th edition barnett'
# 'finite mathematics for business economics life sciences and social sciences 12th edition barnett'
# 	 --->'college','finite'
# ```
# and another one
# ```
# 'mastering the nikon d700'
# 'mastering the nikon d600'
# 	 --->'d700','d600
# ```
#
# We can see what titles are going to be matched :
# *What is interesting here is that the last title contains a repetition of the title inside parenthesis, after the cleaning, we will have removed the parenthesis and will check if the symmetric difference in terms of set of words is empty.*
# ```
# "Jeff Herman's Guide to Book Publishers, Editors & Literary Agents: Who They Are! What They Want! and How to Win Them Over!",
# "Jeff Herman's Guide to Book Publishers, Editors and Literary Agents : Who They Are! What They Want! How to Win Them Over!",
# "Jeff Herman's Guide to Book Publishers, Editors, and Literary Agents: Who They Are! What They Want! How to Win Them Over! (Jeff Herman's Guide to Book Publishers, Editors, & Literary Agents)"
# ```
# *or this second example where a ':' has been replace with a ';'*
# ```
# 'Hawaii the Big Island Revealed: The Ultimate Guidebook',
# 'Hawaii The Big Island Revealed; The Ultimate Guidebook',
# ```
#
#
# While we know that we might be missing a lot of titles, we much rather have less title and 0 false positives than to risk having false positives.

# %% [markdown]
# ## Saving the data using pickle for further analysis
# Now that we have obtained the dataset that we wish to use to conduct our analysis it is time to save it locally to avoid long and repetitive operations while we do the analysis.

# %%
ANALYSIS_DATA_FOLDER = 'analysis_data/'
books_df_path = ANALYSIS_DATA_FOLDER + 'books_full'
review_books_df_path = ANALYSIS_DATA_FOLDER + 'review_books_full'
very_similars_path = ANALYSIS_DATA_FOLDER + 'very_similars_full'

paths = [books_df_path,review_books_df_path,very_similars_path]

# %%
retrieved = []
# Get the file from the dump
if(all(os.path.isfile(p) for p in paths)):
    # We check if the files already exist
    print("Retrieving from :")
    for i,p in enumerate(paths):
        print("\t{}".format(p))
        if(i<2):
            df = pd.read_pickle(p)
            retrieved.append(df)
        else:
            with open(p, 'rb') as handle:
                very_similars = pickle.load(handle)
                retrieved.append(very_similars)
    books_df,review_books_df,very_similars=retrieved
else:
    # Otherwise we create them
    book_only_candidates.loc[very_similar_ASIN].to_pickle(ANALYSIS_DATA_FOLDER + 'books_full')
    review_books.query('asin in @very_similar_ASIN').to_pickle(ANALYSIS_DATA_FOLDER + 'review_books_full')
    with open(ANALYSIS_DATA_FOLDER + 'very_similars_full', 'wb') as handle:
        pickle.dump(very_similars, handle, protocol=pickle.HIGHEST_PROTOCOL)

print("We have retrieved:\n\tbooks_df with shape: {}\n\treview_books_df with shape: {}\n\tvery_similars with length: {}".format(books_df.shape,review_books_df.shape,len(very_similars)))
# Out:
# We have retrieved:
# 	books_df with shape: (6710, 10)
# 	review_books_df with shape: (374282, 3)
# 	very_similars with length: 3173

# %% [markdown]
# ## Finding examples for the data-story

# %% [markdown]
# Because finding similar books is one of the activity that was the most complicated in this work we wanted to find a nice way to show how we did it. Therefore we will try to find a nice example to display in our data story.

# %% [markdown]
# ### Too many books to compare them one to one

# %%
print("In the full dataset we have {} books and  {} reviews".format(meta_books.shape[0],review_books.shape[0]))
books_reviews_count = review_books.groupby('asin').count().overall
asin_enough_reviews = list(books_reviews_count[books_reviews_count > 5].index)
print("We found {} books with enough reviews.".format(len(asin_enough_reviews)))
# Out:
# In the full dataset we have 2370585 books and  22507155 reviews
# We found 625682 books with enough reviews.

# %% [markdown]
# We see that we have $625,682$ different books with at least 5 reviews. Hence if we wanted to compare them one by one we would need to do $391,477,965,124$ comparisons. In order to give an idea of how much time this would take on a consumer computer, we used one of the most common similarity measure ```jaccard_similarity``` and looked at how much time it would take to obtain this score between each possible pair of the dataset.

# %%
def jaccard_similarity(query, document):
    intersection = set(query).intersection(set(document))
    union = set(query).union(set(document))
    return len(intersection)/len(union)

# %%
df = meta_books_reduced.set_index('asin')
df.head()
# Out:
#                                                         title  \
# asin
# 0000913154  The Way Things Work: An Illustrated Encycloped...
# 0001055178                                     Master Georgie
# 0001018043                                The Enchanted Horse
# 0001473727  The Greatest Book on "Dispensational Truth" in...
# 0000230022  The Simple Truths of Service: Inspired by John...
#
#                                                   description  \
# asin
# 0000913154                                                NaN
# 0001055178  Beryl Bainbridge seems drawn to disaster. Firs...
# 0001018043  Grade 3-6-In this fast-paced fantasy, a neglec...
# 0001473727                                                NaN
# 0000230022                                                NaN
#
#                                                         imUrl
# asin
# 0000913154  http://ecx.images-amazon.com/images/I/7113akhD...
# 0001055178  http://ecx.images-amazon.com/images/I/51ZSC6TK...
# 0001018043                                                NaN
# 0001473727  http://ecx.images-amazon.com/images/I/512M299K...
# 0000230022  http://ecx.images-amazon.com/images/I/218uMkP0...

# %%
def on_ten_thousand():
    asins = list(df.index)
    test_asin = asins[0]
    for asin in asins[1:10001]:
        title_1 = df.loc[test_asin]
        title_2 = df.loc[asin]
        jaccard_similarity(title_1,title_2)
    return True

from timeit import default_timer as timer
start = timer()
on_ten_thousand()
end = timer()
print("\nIt would take {} to run on the full dataset.".format(human_readible_time(391477965124/10000*(end - start),3)))
# Out:
# It would take 1288 days, 13:31:28.949 to run on the full dataset.

# %% [markdown]
# Therefore it seems completely undoable to compare them one by one. We had to use another technique to avoid this $O(n^2)$ running time.

# %% [markdown]
# ### Using the power of Hashing

# %% [markdown]
# It would be neat to have a way of reducing the number of comparisons that we have to do. Indeed a method has been developed in order to do such thing. It is called Locality sensitive hashing. It will compute a value on each item. The probability that two items have the same value depends on how similar they are. To simplify things one could thing that we color each book based on the words in its title then we will have two books with similar colors depending on if they have similar words in their title. This mean that we do not need to compare all of them.
#
# One could imagine that each word corresponds to a color (such that very similar words have very similar colors) and that we mix them to obtain the color we associate to the book. Therefore two books with similar titles will have the same color.

# %%
meta_books_reduced = meta_books[meta_books['asin'].isin(asin_enough_reviews)]
meta_books_reduced  = meta_books_reduced [meta_books_reduced ['title'].notnull()]
meta_books_reduced = meta_books_reduced[['asin','title','description','imUrl']]
meta_books_reduced.head()
# Out:
#           asin                                              title  \
# 10  0000913154  The Way Things Work: An Illustrated Encycloped...
# 13  0001055178                                     Master Georgie
# 25  0001018043                                The Enchanted Horse
# 34  0001473727  The Greatest Book on "Dispensational Truth" in...
# 37  0000230022  The Simple Truths of Service: Inspired by John...
#
#                                           description  \
# 10                                                NaN
# 13  Beryl Bainbridge seems drawn to disaster. Firs...
# 25  Grade 3-6-In this fast-paced fantasy, a neglec...
# 34                                                NaN
# 37                                                NaN
#
#                                                 imUrl
# 10  http://ecx.images-amazon.com/images/I/7113akhD...
# 13  http://ecx.images-amazon.com/images/I/51ZSC6TK...
# 25                                                NaN
# 34  http://ecx.images-amazon.com/images/I/512M299K...
# 37  http://ecx.images-amazon.com/images/I/218uMkP0...

# %%
get_candidate_full = candidate_duplicates(meta_books_reduced,'demo/',['title'])
# Out:
# It took 00:01:27.242 to detect duplicates.
# Found 14680 bins of possible duplicates.
# With 36270 different books

# %% [markdown]
# It takes about 1min and 30s to find such duplicates, we reduced the running time from days to minutes. This is significant and we couldn't have done the study if it wasn't for this. Now we have $14,927$ bins of possible similar books. And only $35,742$ books in total in all those bins together.

# %% [markdown]
# ### From candidates similar to similars

# %% [markdown]
# We will in this section see how a bin of similar books from the first step after local sensitive hashing is reduced to true similar books after our matching steps. Because of the randomness in the hashing we will use the same datasets than the one we serialized before hand to have consistent results

# %%
dump_path = DUMP_FOLDER_FULL

#--------after LSH
candidate_lsh,asin_2_similarity_list = candidate_duplicates(meta_books_reduced,dump_path,['title'])

#--------after the API use
amazon_access_file_path = DUMP_FOLDER + "amazon_access_epfl_new"
book_details_df,failed = fill_in_with_details(meta_books_reduced,amazon_access_file_path,candidate_lsh,asin_2_similarity_list,DUMP_FOLDER_FULL)

#--------Working on authors
book_details_df = book_details_df.set_index('asin')
candidate_authors,lsh_to_author = get_similar_authors(book_details_df,candidate_lsh,asin_2_similarity_list)

#--------Refining using the titles
candidate_title,authors_to_title = get_similar_titles(book_details_df,candidate_authors)

print("\nAfter LSH we had {} bins of similar books".format(len(candidate_lsh)))
print("After authors filtering we had {} bins of similar books".format(len(candidate_authors)))
print("After the final step we have {} bins of similar books".format(len(candidate_title)))
# Out:
# Retrieving from :
# 	../../Project-Data-corrected/dump_full/candidate_dup_title_2_100_5_4
#
# Found 14524 bins of possible duplicates.
# With 35871 different books
# It took 00:00:00.060 to import the data.
# Retrieving from :
# 	../../Project-Data-corrected/dump_full/book_only_candidates_with_details
# 	../../Project-Data-corrected/dump_full/api_failed
# It took 00:00:00.144 to get the data.
#
# After LSH we had 14524 bins of similar books
# After authors filtering we had 5880 bins of similar books
# After the final step we have 3173 bins of similar books

# %% [markdown]
# Because we have kept the history of how a group of similar books from lsh is transformed after the two steps we will try to reconstruct the different states:

# %%
progressive_filtering = {}
candidate_lsh,asin_2_similarity_list
for key,asins in candidate_lsh.items():
    after_lsh = asins
    
    keys_in_author = lsh_to_author[key]
    after_authors = [candidate_authors[k] for k in keys_in_author]
    
    keys_in_title = []
    for k in keys_in_author:
        keys_in_title += authors_to_title[k]
    after_titles = [candidate_title[k] for k in keys_in_title]
    
    progressive_filtering[key] = [after_lsh,after_authors,after_titles]

# %% [markdown]
# Because we didn't have a nice example that span over the full filtering we only use one example for the first one and another for the second one.

# %% [markdown]
# #### An example from the first filter

# %% [markdown]
# Now in order to provide a nice example of the first filter we will try to find a bin of similar books from lsh, that lost some members after the first filter

# %%
example_asin = '0517223627'
starting_bin = asin_2_similarity_list[example_asin]
after_lsh,after_authors,after_titles = progressive_filtering[starting_bin]

# %% [markdown]
# **Before the first filter**

# %%
print_details(after_lsh,book_details_df)
# Out:
# Book 1582187916 - title: Alice in Wonderland
# Book 0517223627 - title: Alice in Wonderland
# Book 1481817329 - title: Alice in Wonderland
#
# Book 1582187916 - authors: ['Lewis Carroll']
# Book 0517223627 - authors: ['Lewis Carroll']
# Book 1481817329 - authors: ['Elle Lothlorien']
#
# Book 1582187916 - publisher: Digital Scanning,US
# Book 0517223627 - publisher: Gramercy
# Book 1481817329 - publisher: CreateSpace Independent Publishing Platform
#
# Book 1582187916 - imUrl: http://ecx.images-amazon.com/images/I/51Ego1VvGsL.jpg
# Book 0517223627 - imUrl: http://ecx.images-amazon.com/images/I/517BR28AFJL.jpg
# Book 1481817329 - imUrl: http://ecx.images-amazon.com/images/I/514Ov3cwQkL.jpg

# %% [markdown]
# **After the first filter**

# %%
for k,group in enumerate(after_authors):
    print("---- Group {}".format(k))
    print_details(group,book_details_df)
# Out:
# ---- Group 0
# Book 1582187916 - title: Alice in Wonderland
# Book 0517223627 - title: Alice in Wonderland
#
# Book 1582187916 - authors: ['Lewis Carroll']
# Book 0517223627 - authors: ['Lewis Carroll']
#
# Book 1582187916 - publisher: Digital Scanning,US
# Book 0517223627 - publisher: Gramercy
#
# Book 1582187916 - imUrl: http://ecx.images-amazon.com/images/I/51Ego1VvGsL.jpg
# Book 0517223627 - imUrl: http://ecx.images-amazon.com/images/I/517BR28AFJL.jpg

# %% [markdown]
# #### An example from the second filter

# %%
example_asin_2 = "0312548176"
starting_bin = asin_2_similarity_list[example_asin_2]
after_lsh,after_authors,after_titles = progressive_filtering[starting_bin]

# %% [markdown]
# **Before the second filter**

# %%
for k,group in enumerate(after_authors):
    print("---- Group {}".format(k))
    print_details(group,book_details_df)
# Out:
# ---- Group 0
# Book 125004877X - title: The Walking Dead: The Fall of the Governor: Part One
# Book 0312548176 - title: The Walking Dead: The Fall of the Governor: Part One
# Book 1250052017 - title: The Walking Dead: The Fall of the Governor: Part Two
#
# Book 125004877X - authors: ['Robert Kirkman']
# Book 0312548176 - authors: ['Robert Kirkman', 'Jay Bonansinga']
# Book 1250052017 - authors: ['Robert Kirkman', 'Jay Bonansinga']
#
# Book 125004877X - publisher: St. Martin's Griffin
# Book 0312548176 - publisher: Thomas Dunne Books
# Book 1250052017 - publisher: Thomas Dunne Books
#
# Book 125004877X - imUrl: http://ecx.images-amazon.com/images/I/912OzuzR5nL.jpg
# Book 0312548176 - imUrl: http://ecx.images-amazon.com/images/I/51YJJxTueuL.jpg
# Book 1250052017 - imUrl: http://ecx.images-amazon.com/images/I/51BCcT50zdL.jpg

# %% [markdown]
# **After the second filter**

# %%
for k,group in enumerate(after_titles):
    print("---- Group {}".format(k))
    print_details(group,book_details_df)
# Out:
# ---- Group 0
# Book 125004877X - title: The Walking Dead: The Fall of the Governor: Part One
# Book 0312548176 - title: The Walking Dead: The Fall of the Governor: Part One
#
# Book 125004877X - authors: ['Robert Kirkman']
# Book 0312548176 - authors: ['Robert Kirkman', 'Jay Bonansinga']
#
# Book 125004877X - publisher: St. Martin's Griffin
# Book 0312548176 - publisher: Thomas Dunne Books
#
# Book 125004877X - imUrl: http://ecx.images-amazon.com/images/I/912OzuzR5nL.jpg
# Book 0312548176 - imUrl: http://ecx.images-amazon.com/images/I/51YJJxTueuL.jpg

# %% [markdown]
# # Correlation analysis

# %% [markdown]
# First of all, we want to perform an analysis of the reviews and how they are correlated with important indicators of Amazon such as sales rank and price. This section will contain an overview of our research, nevertheless we were pretty disappointed by the results concerning the correlation between the review average and the sales rank (as we will see later on and try to justify).

# %% [markdown]
# ## Reviews analysis

# %%
books_df.head(3)
# Out:
#                                        title  \
# asin
# 1453728988                          The Walk
# 1455885002                          The Walk
# 0967396972  Pocket Guide to Low Sodium Foods
#
#                                                   description  \
# asin
# 1453728988  "More than anything, THE WALK is a story that ...
# 1455885002  "More than anything, THE WALK is a story that ...
# 0967396972  Bobbie Mostynis an advocate of the low-salt li...
#
#                                                         imUrl  \
# asin
# 1453728988  http://ecx.images-amazon.com/images/I/51HyJC88...
# 1455885002  http://ecx.images-amazon.com/images/I/710vT6L7...
# 0967396972  http://ecx.images-amazon.com/images/I/71TyNwAc...
#
#                     authors                                    publisher  \
# asin
# 1453728988   [lee goldberg]  Createspace Independent Publishing Platform
# 1455885002   [lee goldberg]                       Brilliance Corporation
# 0967396972  [bobbie mostyn]                                 Indata Group
#
#                   ISBN sales_rank_updated binding                     edition  \
# asin
# 1453728988  1453728988             325453  Broché                        None
# 1455885002  1455885002               None  MP3 CD                  Unabridged
# 0967396972  0967396972               None  Broché  Revised, Updated, Expanded
#
#            release_date
# asin
# 1453728988         None
# 1455885002         None
# 0967396972         None

# %%
review_books_df.head(3)
# Out:
#              asin  overall unixReviewTime
# 19310  0006136540      4.0     2009-10-03
# 19311  0006136540      4.0     2010-09-04
# 19312  0006136540      5.0     2009-07-21

# %% [markdown]
# ### Reviews distribution
# First of all we look at the distribution of the reviews.

# %%
review_total = len(review_books_df)
distribution = review_books_df.groupby('overall')[['asin']].count()*100/review_total

# %%
distribution.columns = ['percentage']
plt.figure(figsize=(14,5))
plt.bar(distribution.index.values, distribution.values, align='center')
plt.title('Distribution of ratings')
plt.xlabel('Ratings')
plt.ylabel('Percentage')
plt.grid()
plt.show()

# %% [markdown]
# We see that most of our reviews (65%) have a grade of 5. We will use this distribution in order to split our ratings into three categories (H,M,L later on). We see that it is going to be hard to have three balanced class due to the heavy right skew of the histogram.

# %%
distribution.head()
# Out:
#          percentage
# overall
# 1.0        5.016271
# 2.0        3.830000
# 3.0        7.183087
# 4.0       17.837620
# 5.0       66.133023

# %% [markdown]
# ### Evolution of reviews over time
# Then we wanted to observe how reviews submission changes over time, that is show how reviews are distributed over time.

# %%
review_books_df.sort_values(by='unixReviewTime').head()
# Out:
#                 asin  overall unixReviewTime
# 7382362   0671003755      5.0     1996-11-20
# 4425969   0385260954      5.0     1997-07-20
# 6149991   0471111813      1.0     1997-08-07
# 785308    0062008110      5.0     1997-08-09
# 10645314  0891458190      5.0     1997-08-11

# %%
distribution = review_books_df.groupby(review_books_df['unixReviewTime'].apply(
    lambda x: x.year)).count() * 100 / review_total

plt.figure(figsize=(14, 5))
plt.bar(distribution.index.values, distribution['asin'].values, align='center')
plt.title('Distribution of reviews')
plt.xlabel('Years of publication')
plt.ylabel('Percentage')
plt.grid()
plt.show()

# %% [markdown]
# One can observe that the reviews have been mostly submitted in the past 10 years.

# %%
distribution_std = review_books_df.groupby(
    review_books_df['unixReviewTime'].apply(lambda x: x.year)).std()
distribution_count = review_books_df.groupby(
    review_books_df['unixReviewTime'].apply(lambda x: x.year)).count()
distribution_err = distribution_std

for index, row in distribution_std.iterrows():
    distribution_err.loc[index].err = 2 * distribution_std.loc[
        index].overall / np.sqrt(distribution_count.loc[index].overall)

distribution_err.tail()
# Out:
#                  overall
# unixReviewTime
# 2010            1.217712
# 2011            1.226820
# 2012            1.115042
# 2013            0.986702
# 2014            0.967789

# %%
distribution = review_books_df.groupby(review_books_df['unixReviewTime'].apply(lambda x: x.year)).mean()

plt.figure(figsize=(14,5))
plt.plot(distribution.index.values, distribution['overall'].values)
axes = plt.gca()
axes.set_ylim([0,5])
plt.title('Distribution of reviews')
plt.xlabel('Years of publication')
plt.ylabel('Mean rating')
plt.grid()
plt.show()

# %% [markdown]
# We see that the review average remains stable around 4.2 out of 5 over time.

# %% [markdown]
# ## How reviews influence the sales rank
# Amazon itself doesn’t reveal exactly how the sales rank is calculated, which is why there are only theories and speculation surrounding the method. In our analysis, we want to see if their is a statistic correlation between sales rank and reviews grade.

# %% [markdown]
# ### On the books in the similar dataset
#
# We will study the correlation of reviews with sales rank only on the dataset formed by books that have been found to be similar to another one as those are the one that we use later on to study the Herding effect.

# %%
very_similar_ASIN = [item for sublist in list(very_similars.values()) for item in sublist]

meta_books_df = pd.read_pickle('../../Project-Data/dump/meta_Books_asin_title_salesRank_description_imUrl_ALL')
meta_books_df = meta_books_df[['asin', 'description', 'imUrl', 'salesRank_Books', 'title']].set_index('asin').loc[very_similar_ASIN]

meta_reviews_df = pd.read_pickle('../../Project-Data/dump/reviews_Books_asin_overall_unixReviewTime_ALL')

meta_books_df.shape
# Out:
# (6711, 4)

# %% [markdown]
# These 3 books are the best ranked of our dataframe. They have the smallest sales rank.

# %%
meta_books_df.sort_values(by='salesRank_Books').head(3)
# Out:
#                                                   description  \
# asin
# 053847808X  William Pride (Ph.D., Louisiana State Universi...
# 0375842209  Starred Review.Grade 9 Up–Zusak has created a ...
# 0316017930  Amazon Best of the Month, November 2008: Now t...
#
#                                                         imUrl  \
# asin
# 053847808X  http://ecx.images-amazon.com/images/I/41m-2mub...
# 0375842209  http://ecx.images-amazon.com/images/I/51eQvANU...
# 0316017930  http://ecx.images-amazon.com/images/I/41h5QL0v...
#
#             salesRank_Books                           title
# asin
# 053847808X             14.0                        Business
# 0375842209             23.0                  The Book Thief
# 0316017930             41.0  Outliers: The Story of Success

# %% [markdown]
# We create the dataframe that we want for our analysis. The columns are ```asin```, ```salesRank```, ```review_avg``` for the average of review grade for corresponding to the book, and ```review_count``` for the sum of reviews.

# %%
# We group reviews thanks to their ASIN
grouped = meta_reviews_df.groupby('asin')
# We compute the average and the number of reviews
review_count = meta_reviews_df.groupby('asin').count().reset_index()
review_avg = meta_reviews_df.groupby('asin').mean().reset_index()
# We merge those two with the metadata of the books
df = pd.merge(meta_books_df.reset_index(), review_avg, on='asin')
df = pd.merge(df, review_count, on='asin')

# %%
# Then we format the dataframe to have meaningful columns and indices
df = df[['asin','salesRank_Books','overall_x','overall_y']]
df.columns = ['asin','salesRank','review_avg','review_count']
df.set_index('asin',inplace=True)
df.head()
# Out:
#             salesRank  review_avg  review_count
# asin
# 1455885002  2272808.0    3.869565            23
# 1453728988   253224.0    3.844687           734
# 0967396964   251202.0    3.964286            28
# 0967396913   365470.0    4.500000            10
# 0967396972    93326.0    4.142857            21

# %% [markdown]
# We plot our datas to see if we can observe trends.

# %%
pearson_corr = df.corr()
spearman_corr = df.corr(method='spearman')
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=False, figsize=(18, 10))
sns.regplot("salesRank", "review_avg", data=df, color="b", ax=ax1)
sns.regplot("salesRank", "review_count", data=df, color="b", ax=ax2)
sns.regplot("review_count", "review_avg", data=df, color="b", ax=ax3)

axes1 = ax1.axes
axes1.set_xlim(3000000,1)
axes1.set_title("pearson = {}, spearman = {}".format(pearson_corr.loc['review_avg','salesRank'].round(2),spearman_corr.loc['review_avg','salesRank'].round(2)))

axes2 = ax2.axes
axes2.set_xlim(3000000, 1)
axes2.set_ylim(0,300)
axes2.set_title("pearson = {}, spearman = {}".format(pearson_corr.loc['review_count','salesRank'].round(2),spearman_corr.loc['review_count','salesRank'].round(2)))

axes3 = ax3.axes
axes3.set_xlim(0,300)
axes3.set_title("pearson = {}, spearman = {}".format(pearson_corr.loc['review_count','review_avg'].round(2),spearman_corr.loc['review_count','review_avg'].round(2)))

# %% [markdown]
# Unfortunately, because we only visualize a subset of the amazon dataset, the scale for the sales rank ranges over a large interval. The pearson and spearman correlation scores do not find a meaningful relationship between the columns of interest except for the review count where it seems to negatively correlated with the sales rank (the more reviews, the lower the sales rank which means that the sales rank depends on the number of reviews, the more reviews the better the sales rank. This could be explained by the fact that the number of reviews is also dependent on the number of sales). In order to mitigate this problem we will modify the ranks.

# %% [markdown]
# ### Modifying the ranks

# %% [markdown]
# #### Obtaining a continuous sales rank

# %% [markdown]
# In order to spread the points and to have a ranking that is continuous we induce a new ranking, we will consider all the unique sales rank in increasing order and will assign them increasing ranks.

# %%
df_restricted = df[df['salesRank'].notnull()]
df_restricted = df_restricted.sort_values('salesRank')
ranking_map = {}
for (i,v) in enumerate(df_restricted['salesRank'].unique()):
    ranking_map[v] = i+1
df_restricted['deduced_rank'] = df_restricted['salesRank'].map(lambda x : ranking_map[x])

# %%
df_restricted.head()
# Out:
#             salesRank  review_avg  review_count  deduced_rank
# asin
# 053847808X       14.0    4.076923            13             1
# 0375842209       23.0    4.692308            13             2
# 0316017930       41.0    4.142857            14             3
# 0307352153       81.0    4.500000             6             4
# 0385349947      150.0    4.338917          1791             5

# %%
pearson_corr = df_restricted.corr()
spearman_corr = df_restricted.corr(method='spearman')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=False, figsize=(18, 10))
sns.regplot("deduced_rank", "review_avg", data=df_restricted, color="b", ax=ax1)
sns.regplot("deduced_rank", "review_count", data=df_restricted, color="b", ax=ax2)
sns.regplot("review_count", "review_avg", data=df_restricted, color="b", ax=ax3)
axes1 = ax1.axes
axes1.set_title("pearson = {}, spearman = {}".format(pearson_corr.loc['deduced_rank','review_avg'].round(2),spearman_corr.loc['deduced_rank','review_avg'].round(2)))

axes2 = ax2.axes
axes2.set_ylim(0,300)
axes2.set_title("pearson = {}, spearman = {}".format(pearson_corr.loc['deduced_rank','review_count'].round(2),spearman_corr.loc['deduced_rank','review_avg'].round(2)))

axes3 = ax3.axes
axes3.set_xlim(0,300)
axes3.set_title("pearson = {}, spearman = {}".format(pearson_corr.loc['review_count','review_avg'].round(2),spearman_corr.loc['deduced_rank','review_avg'].round(2)))

# %% [markdown]
# From these plot we can hardly deduce anything, nevertheless we can go a bit further by trying to guess a ranking based on the review average. Then plot it against the deduced rank to see how it correlates to it. If the sales rank is depending heavily on the review grade then it should have a pearson correlation close to 1.

# %% [markdown]
# #### Deducing a rank from the review average

# %%
df_restricted.sort_values(by='review_avg',ascending=False,inplace=True)
review_ranking_map = {}
for (i,v) in enumerate(df_restricted['review_avg'].unique()):
    review_ranking_map[v] = i+1
df_restricted['review_rank'] = df_restricted['review_avg'].map(lambda x : review_ranking_map[x])
df_restricted.head()
# Out:
#             salesRank  review_avg  review_count  deduced_rank  review_rank
# asin
# 031033103X   237602.0         5.0             7          2775            1
# 157432246X  1885538.0         5.0             6          6201            1
# 1402771185   967581.0         5.0             6          5289            1
# 0199538859    53561.0         5.0            13          1209            1
# 1401938779   284241.0         5.0             7          3028            1

# %%
pearson_corr = df_restricted.corr()
spearman_corr = df_restricted.corr(method='spearman')

# %%
sns.regplot(
    "review_rank", "deduced_rank", data=df_restricted,
    color="b").set_title("pearson = {}, spearman = {}".format(
        pearson_corr.loc['review_rank', "deduced_rank"].round(2),
        spearman_corr.loc['review_rank', "deduced_rank"].round(2)))

# %%
sns.regplot(
    "review_rank", "salesRank", data=df_restricted,
    color="b").set_title("pearson = {}, spearman = {}".format(
        pearson_corr.loc['review_rank', "salesRank"].round(2),
        spearman_corr.loc['review_rank', "salesRank"].round(2)))

# %% [markdown]
# Again the correlation of this rank with either the real ```sales_rank``` or the ```deduced_rank``` is not significant to be even considered. We thought that maybe this could be due to the presence in our data of books with very low review and therefore not very significant review averages. We know that by reducing the dataset to only encompass books with more than a given number of reviews we might introduce a bias (the sales rank could also be correlated with the number of reviews).

# %% [markdown]
# #### Considering books with sufficient number of reviews

# %% [markdown]
# We aribitrarly decided to consider that the median of the number of reviews would be a good threshold.

# %%
df_restricted['review_count'].median()
# Out:
# 15.0

# %%
median = df_restricted['review_count'].median()
df_restricted = df_restricted[df_restricted['review_count']> median]

# we compute a review rank again
df_restricted.sort_values(by='review_avg',ascending=False,inplace=True)
review_ranking_map = {}
for (i,v) in enumerate(df['review_avg'].unique()):
    review_ranking_map[v] = i+1
df_restricted['review_rank'] = df_restricted['review_avg'].map(lambda x : review_ranking_map[x])

# as well as a deduced rank
df_restricted = df_restricted[df_restricted['salesRank'].notnull()]
df_restricted = df_restricted.sort_values('salesRank')
ranking_map = {}
for (i,v) in enumerate(df_restricted['salesRank'].unique()):
    ranking_map[v] = i+1
df_restricted['deduced_rank'] = df_restricted['salesRank'].map(lambda x : ranking_map[x])

df_restricted.corr().loc[['salesRank','deduced_rank']]
# Out:
#               salesRank  review_avg  review_count  deduced_rank  review_rank
# salesRank      1.000000   -0.069192     -0.027246      0.644355     0.005478
# deduced_rank   0.644355   -0.071404     -0.082608      1.000000    -0.067520

# %%
df_restricted.corr(method='spearman').loc[['salesRank','deduced_rank']]
# Out:
#               salesRank  review_avg  review_count  deduced_rank  review_rank
# salesRank           1.0   -0.060383     -0.215805           1.0    -0.071779
# deduced_rank        1.0   -0.060383     -0.215805           1.0    -0.071779

# %% [markdown]
# We expected to see a much clearer positive correlation between the sales rank and the review average. But these results are not surprising, the sales of an item might not only depend on the review average. This is partly due to the fact that the review average is a static value considered over all the reviews but each sale depends only the previous reviews. Also many other variable could explain such results.
#
# We will therefore rely for the herding effect on the intuition that a customer that has the choice between two identical products will chose the one with the highest average rating (assuming all other parameters constant)

# %% [markdown]
# ### Comparison of books that are similar
#
# Now we want to see if two similar books with different sales rank have different reviews' characteristics.

# %%
df = df[['salesRank','review_avg','review_count']]
df.head(3)
# Out:
#             salesRank  review_avg  review_count
# asin
# 1455885002  2272808.0    3.869565            23
# 1453728988   253224.0    3.844687           734
# 0967396964   251202.0    3.964286            28

# %% [markdown]
# Now we will compare the books that are similar to see how the difference in their review average relates to the difference in salesRank.

# %%
dump_path = ANALYSIS_DATA_FOLDER + 'books_diff'
if(os.path.isfile(dump_path)):
    books_salesrank_reviews_diff_df = pd.read_pickle(dump_path)
else:
    books_salesrank_reviews_diff = []

    for i,similar_bins in enumerate(very_similars.values()):
        all_details = [df.loc[asin] for asin in similar_bins]
        
        combin = combinations(all_details, 2)

        for pair in combin:
            diff_salesrank = pair[0].salesRank - pair[1].salesRank
            diff_review_avg = pair[0].review_avg - pair[1].review_avg
            diff_review_count = pair[0].review_count - pair[1].review_count
            
            books_salesrank_reviews_diff.append({
                'diff_salesrank': diff_salesrank,
                'diff_review_avg': diff_review_avg,
                'diff_review_count': diff_review_count,
            })
            
        progress(i, len(very_similars), suffix='')
        
    books_salesrank_reviews_diff_df = pd.DataFrame.from_dict(books_salesrank_reviews_diff) 
    
    with open(dump_path, 'wb') as handle:
        pickle.dump(books_salesrank_reviews_diff_df, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print("\nSaved to {}.".format(dump_path))

# %%
books_salesrank_reviews_diff_df.head()
# Out:
#    diff_review_avg  diff_review_count  diff_salesrank
# 0         0.024879             -711.0       2019584.0
# 1        -0.535714               18.0       -114268.0
# 2        -0.178571                7.0        157876.0
# 3         0.357143              -11.0        272144.0
# 4         0.242424               -7.0        129049.0

# %%
books_salesrank_reviews_diff_df.corr().loc[['diff_salesrank']]
# Out:
#                 diff_review_avg  diff_review_count  diff_salesrank
# diff_salesrank         0.008787          -0.017407             1.0

# %% [markdown]
# Unfortunately there isn't much that can be said from this data.

# %% [markdown]
# ## How reviews influence the price
#
# As we cover the sales rank correlation analysis with reviews, we perform an analysis about book prices.
#
# ### Comparison of books together
#
# We decide this time to take a part of all the dataset to perform our analysis between books together. Price and Review correlation analysis

# %%
meta_books_path, review_books_path, core_book_path = get_paths(0, DATA_FOLDER, META_FOLDER,CORE_FOLDER,REVIEWS_FOLDER, CATEGORIES)
# Out:
# Paths :
# 	 meta = ../../Project-Data-corrected/meta/meta_Books.json
# 	 review = ../../Project-Data-corrected/reviews/reviews_Books.json
# 	 core_path = ../../Project-Data-corrected/5_core/Books.json

# %%
meta_books = import_interesting_cols(meta_books_path,DUMP_FOLDER,True,[],max_count=MAXCOUNT)
# Out:
# Retrieving from : ../../Project-Data-corrected/dump/meta_Books__ALL
# It took 00:01:20.916 to import the data.

# %% [markdown]
# We want to know if there is a correlation between book price and reviews. For the reviews, we will use the average and the quantity for each book.
#
# We see that the price is not available for each books. We will not use books without price for our analysis. We create the dataframe that we want for our analysis where columns are ```asin```, ```price```, ```review_avg```, ```review_count```.

# %%
meta_books.head()
# Out:
#          asin brand categories  \
# 0  0001048791   NaN    [Books]
# 1  0001048775   NaN    [Books]
# 2  0001048236   NaN    [Books]
# 3  0000401048   NaN    [Books]
# 4  0001019880   NaN    [Books]
#
#                                          description  \
# 0                                                NaN
# 1  William Shakespeare is widely regarded as the ...
# 2  "One thing is certain, Sherlockians, put aside...
# 3                                                NaN
# 4                                                NaN
#
#                                                imUrl  price  \
# 0  http://ecx.images-amazon.com/images/I/51MKP0T4...    NaN
# 1  http://ecx.images-amazon.com/images/I/5166EBHD...    NaN
# 2  http://ecx.images-amazon.com/images/I/51DH145C...   9.26
# 3  http://ecx.images-amazon.com/images/I/41bchvIf...    NaN
# 4  http://ecx.images-amazon.com/images/I/61LcHUdv...   5.39
#
#                                              related  \
# 0                                                NaN
# 1                                                NaN
# 2  {'also_viewed': ['1442300191', '9626349786', '...
# 3                    {'also_viewed': ['068240103X']}
# 4  {'also_viewed': ['B003HMB5FC', '0834004593'], ...
#
#    salesRank_Arts,_Crafts_&_Sewing  salesRank_Books  \
# 0                              NaN        6334800.0
# 1                              NaN       13243226.0
# 2                              NaN        8973864.0
# 3                              NaN        6448843.0
# 4                              NaN        9589258.0
#
#    salesRank_Cell_Phones_&_Accessories  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                          ...                          salesRank_Jewelry  \
# 0                        ...                                        NaN
# 1                        ...                                        NaN
# 2                        ...                                        NaN
# 3                        ...                                        NaN
# 4                        ...                                        NaN
#
#    salesRank_Kitchen_&_Dining  salesRank_Movies_&_TV  salesRank_Music  \
# 0                         NaN                    NaN              NaN
# 1                         NaN                    NaN              NaN
# 2                         NaN                    NaN              NaN
# 3                         NaN                    NaN              NaN
# 4                         NaN                    NaN              NaN
#
#    salesRank_Musical_Instruments  salesRank_Office_Products  salesRank_Shoes  \
# 0                            NaN                        NaN              NaN
# 1                            NaN                        NaN              NaN
# 2                            NaN                        NaN              NaN
# 3                            NaN                        NaN              NaN
# 4                            NaN                        NaN              NaN
#
#    salesRank_Sports_&_Outdoors  salesRank_Toys_&_Games  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#                                                title
# 0  The Crucible: Performed by Stuart Pankin, Jero...
# 1         Measure for Measure: Complete & Unabridged
# 2               The Sherlock Holmes Audio Collection
# 3  The rogue of publishers' row;: Confessions of ...
# 4          Classic Soul Winner's New Testament Bible
#
# [5 rows x 25 columns]

# %%
dump_path = ANALYSIS_DATA_FOLDER + 'books_price_reviews'
# We group reviews thanks to their ASIN
grouped = meta_reviews_df.groupby('asin')
# We compute the average and the number of reviews
review_count = meta_reviews_df.groupby('asin').count().reset_index()
review_avg = meta_reviews_df.groupby('asin').mean().reset_index()
# We merge those two with the metadata of the books
df = pd.merge(meta_books.reset_index(), review_avg, on='asin')
books_price_reviews_df = pd.merge(df, review_count, on='asin')
books_price_reviews_df = books_price_reviews_df[books_price_reviews_df['price'].notnull()]

# %%
# Then we format the dataframe to have meaningful columns and indices
books_price_reviews_df = books_price_reviews_df[['asin','salesRank_Books','overall_x','overall_y','price']]
books_price_reviews_df.columns = ['asin','salesRank','review_avg','review_count','price']
books_price_reviews_df.set_index('asin',inplace=True)
books_price_reviews_df.head()
# Out:
#              salesRank  review_avg  review_count  price
# asin
# 0001048236   8973864.0         5.0             1   9.26
# 0001019880   9589258.0         5.0             2   5.39
# 0001053396  12249714.0         4.0             1  17.99
# 0000913154    455782.0         5.0             8  23.26
# 0001053744   5665835.0         5.0             1   6.05

# %% [markdown]
# This are the 3 most expensives books from our selection.

# %%
books_price_reviews_df.sort_values(by='price',ascending=False).head(3)
# Out:
#              salesRank  review_avg  review_count   price
# asin
# B000Q02QVK   1762034.0         5.0             2  999.99
# B007O0Z996         NaN         4.0             3  999.00
# 1460987241  11230757.0         1.0             1  999.00

# %%
pearson_corr = books_price_reviews_df.corr()
spearman_corr = books_price_reviews_df.corr(method='spearman')
pearson_corr.loc[['price']]
# Out:
#        salesRank  review_avg  review_count  price
# price   0.032815   -0.022041     -0.040499    1.0

# %%
spearman_corr.loc[['price']]
# Out:
#        salesRank  review_avg  review_count  price
# price  -0.034519    0.061528     -0.211818    1.0

# %% [markdown]
# We do observe on the spearman correlation that the review count is (slightly) negatively correlated with the the price. This is quite intuitive as expensive items tend to be less bought and therefore will have less reviews.

# %% [markdown]
# # Herding Effect analysis

# %% [markdown]
# Now that we have seen that it is hard to show conclusive results regarding reviews and other product characteristics (price, sales rank, and other correlation analysis). We want to study how the first review influence the others or the so called "herding effect".

# %% [markdown]
# In this analysis we will need the books matched from the first step. We realised this Herding Effect analysis in two steps. We first validated our hypothesis of herding effect on a small dataset of arround 880 pair of books and then we took a step further and tried to validate it again on a bigger dataset (3720 pairs of books). Only the second step is present in this milestone as similar but more complete results are observable on the larger dataset.

# %%
# load the data from the matching step
books_df = pd.read_pickle(ANALYSIS_DATA_FOLDER + 'books_full')
review_books_df = pd.read_pickle(ANALYSIS_DATA_FOLDER + 'review_books_full')
with open(ANALYSIS_DATA_FOLDER + 'very_similars_full', 'rb') as handle:
    very_similars = pickle.load(handle)

# %% [markdown]
# ## Pre-analysis
#
# Before going any further in the herding effect analysis, this very first step is focused on gathering the data from the matching and categorize each pair of similar book into different categories that are going to be used in our futur analysis.
#
# As a starting point, we will add a first_review_overall column in our books_df. It will contain the first rating of this particular book. And will help us at many occasion in our analysis.

# %%
# we add to each books his first review overall rating
books_df['first_review_overall'] = books_df.apply(lambda x: return_first_review_overall(x, review_books_df), 1)

# %% [markdown]
# A second required and important step was to create a "matching_df that" contains every possible pair matched from previous matching step with every possible combinations.

# %%
# create a flat matching DF with every unique possible pair including combination
matching_df = pd.DataFrame(columns=['asin_1', 'asin_2'])
for similar_bins in very_similars.values():
    for asin1,asin2 in itertools.combinations(similar_bins, 2):
        matching_df = matching_df.append({'asin_1': asin1, 'asin_2': asin2}, ignore_index=True)
matching_df.head()
# Out:
#        asin_1      asin_2
# 0  1455885002  1453728988
# 1  0967396964  0967396913
# 2  0967396964  0967396972
# 3  0967396913  0967396972
# 4  1429203161  1429233419

# %%
matching_df.shape
# Out:
# (3990, 2)

# %% [markdown]
# Then for the needs of our analysis, we need to split our data in different categories according to their first review overall. Some will be categorized as High first review (H), some will be categorized as Low first review (L). We also tried different combination of H and L with different treshold. We also introduce a (M) level or medium first review rating.

# %% [markdown]
# #### H/M/L Categorization
#
# By trying different combination during milestone 2 and looking at the repartition of the ratings in the second part of this notebook. Best results were found with a High first review (H) set to a first review being equal to 5, a Medium first review (M) set to a first review being equal to 4 and finally a Low first review (L) set to a first review being in a range from 1 to 3. This is what results in the most balanced categorization.

# %%
# We show a graphical representation of the categorization.
review_total = len(review_books_df)
distribution = review_books_df.groupby('overall')[['asin']].count()*100/review_total
category = {1.0:'L',2.0:'L',3.0:'L',4.0:'M',5.0:'H'}
distribution.reset_index(inplace=True)
distribution['category'] = distribution['overall'].map(category)
distribution.columns = ['overall','percentage','category']


colors = {'L':0,'M':1,'H':2}
distribution['color'] = distribution['category'].map(lambda x: sns.color_palette()[colors[x]])
g = sns.barplot(x="overall", y="percentage",data=distribution,palette=distribution['color'])

# %% [markdown]
# Again for clarity we decided to display for this milestone only the final working category repartition and discard the other attempts shown in milestone 2 if needed.

# %%
matching_df['type'] = matching_df.apply(lambda x: 
                                        categorize_pair(x, return_category_from_value_HML, books_df), axis=1)
matching_df.groupby('type').count()
# Out:
#       asin_1  asin_2
# type
# HH      1787    1787
# HL       375     375
# HM       427     427
# LH       434     434
# LL       182     182
# LM       132     132
# MH       392     392
# ML       133     133
# MM       128     128

# %% [markdown]
# And before drawing any conclusion let's aggregate similair pair such as LH and HL.

# %%
# aggregate LH and HL by swaping the value in the dataframe
matching_df[matching_df.type == "LH"] = matching_df.query('type == "LH"').reindex(columns=['asin_2', 'asin_1', 'type'])
matching_df.loc[matching_df.type == "LH", "type"] = "HL"

# aggregate MH and HM by swaping the value in the dataframe
matching_df[matching_df.type == "MH"] = matching_df.query('type == "MH"').reindex(columns=['asin_2', 'asin_1', 'type'])
matching_df.loc[matching_df.type == "MH", "type"] = "HM"

# aggregate LM and LM by swaping the value in the dataframe
matching_df[matching_df.type == "LM"] = matching_df.query('type == "LM"').reindex(columns=['asin_2', 'asin_1', 'type'])
matching_df.loc[matching_df.type == "LM", "type"] = "ML"

matching_df.groupby('type').count()
# Out:
#       asin_1  asin_2
# type
# HH      1787    1787
# HL       809     809
# HM       819     819
# LL       182     182
# ML       265     265
# MM       128     128

# %% [markdown]
# Now we observe that interestingly enough we have a significant part of our dataset falling into the ```HH``` category. This is not surprising when we look at the repartition of the rating from part 2.
#
# The other important thing to note here is that we now have enough data to explore almost every category. Indeed in our small scale analysis of milestone 2 we had meaningful insight for categories with around 150 data points. Here we can see that every category is above that. This observation is good for our analysis as it means that it will allow us to study and validate our hypothesis on more category this time than during milestone 2.

# %% [markdown]
# ### Herding Effect Analysis

# %% [markdown]
# #### Introduction
#
# The herding effect is observed when rating a product or a customer is biased to follow other customers's previous rating on the same product. In this study of the Herding Effect on Amazon reviews dedicated to the book category, we are going to focus mostly on how the first review on 2 similar products can influence latter reviews.

# %% [markdown]
# #### A first example

# %% [markdown]
# To better understand what is the herding effect and what it could mean on the review of a product, let's draw and example of such a case. After matching each pair of product together in the previous step, and assign some categories to them ("HH", "HM", "HL", "MM", "ML"). We are going to choose a matching pair with the highest possible difference in order to be able to clearly see the effect (i.e. in the "HL" category).

# %%
highest_diff = matching_df.query('type == "HL"').apply(lambda x: find_highest_diff(x['asin_2'], books_df), axis=1)
highest_diff.sum()
# Out:
# 266

# %% [markdown]
# We find that there is 266 cases in our dataset with 2 very similar products having in one case a first rating of 1 star against a first rating of 5 stars. We take as example one of such a case to demonstrate the Herding Effect.

# %%
# take one of the matches as example
match = matching_df.query('type == "HL"')[highest_diff].iloc[12]
asin_1 = match.asin_1
asin_2 = match.asin_2

# observe that they are indeed very similar books
interesting_cols = ['title', 'authors', 'publisher','imUrl']
for col in interesting_cols:
    print('Book 1 - {}: {}'.format(col, books_df.loc[asin_1][col]))
    print('Book 2 - {}: {}'.format(col, books_df.loc[asin_2][col]))
    print()
# Out:
# Book 1 - title: What to Expect When You're Expecting
# Book 2 - title: What to Expect When You're Expecting
#
# Book 1 - authors: ['heidi murkoff', 'arlene eisenberg', 'sandee hathaway']
# Book 2 - authors: ['heidi murkoff', 'arlene eisenberg', 'sandee hathaway']
#
# Book 1 - publisher: Workman Publishing
# Book 2 - publisher: Workman Publishing
#
# Book 1 - imUrl: http://ecx.images-amazon.com/images/I/51H9J65DPJL.jpg
# Book 2 - imUrl: http://ecx.images-amazon.com/images/I/5156XAF3Y4L.jpg

# %% [markdown]
# Looking at the details from above we can confirm that we are talking about the same book. Everything matches...
#
# However in one case (book 1) the first review rating is 5 and in the other case the first review is 1. This is the ideal case (Book 2) to observe the herding effect and see the influence of the first review on the followings.
#
# And as we know a picture is worth a thousand words, in the next step, we are going to draw 2 graphs  to show the herding effect behaviour on this particular book example.

# %%
data_1 = review_books_df.query('asin == @asin_1').sort_values('unixReviewTime')
data_2 = review_books_df.query('asin == @asin_2').sort_values('unixReviewTime')
plot_example_rat_and_cumrat_subplots(data_1, data_2)

# %% [markdown]
# This example is very special as we can see that the cumulative average rating don't converge to a common value and the herding effect seem to never really end. Looking at the ratings for each book we can clearly see that on average the rating of the first book are much higher than those of the second book.
#
# Even though this example is particularly interesting, it would be more appealing to generalize such results. Nevertheless, looking at the effect on a particular example can help us grasp the theory we are trying to demonstrate on the whole dataset.

# %% [markdown]
# #### Generalization
#
# We are going to study here every groups independtly HH, MM, LL, HM, HL and ML. Since we now have enough data to draw a generalization on the herding effect for each of these groups. To measure the herding effect on our dataset, we are going to compare the i-th rating between similar products in each group respectively. If we observe a positive difference between these values, it would supports the hypothesis of a causal link between the first rating and the following ones. We should also be able to see until what index this effect can be observed.
#
# We use HH, MM and LL as a testing groups in which we should not have any influence from the herding effect, HM and ML should have a moderated impact and finally the most interesting category should be HL in which we should really see the impact of the herding effect.

# %%
# find for each books in each pair of type HL the 5 first reviews
result = matching_df.query('type == "HL"').apply(lambda x: find_n_reviews(x, 5, review_books_df), 1)

# create 2 df based on the result of our functions with the 5 reviews as columns
H_in_HL_df = pd.DataFrame([x[0] for x in result])
L_in_HL_df = pd.DataFrame([x[1] for x in result])

# compute the interesting stats for each reviews (mean and 95% confidence interval)
H_in_HL_stats = compute_stats_on_reviews_df(H_in_HL_df)
L_in_HL_stats = compute_stats_on_reviews_df(L_in_HL_df)

# plot the result in a nice errorbar plot
plot_stats_bar_plot('Average Rating following H/L first rating',
                    H_in_HL_stats, light_green, 'H in HL', L_in_HL_stats, light_red, 'L in HL')

# %% [markdown]
# As we can see just above, the results are mitigate we can observe that the 2-3 reviews after a bad first reviews tends to be in average lower than when the first review is good. However after that it seems that everything come back to normal and the herding effect has no longer impact. Finally the reviews tends to converge to a same average value which is good given the fact that they are supposed to be similar books afterall.
#
# Having now more than 700 datapoints at hand to confirm our theory from milestone 2 and observing quite similar result is encouraging for the validity of our theory regarding the herding effect.

# %% [markdown]
# Now let's see if we can observe the effect a little more and look only at the most extreme difference in first rating (1 and 5 stars). In our first analysis we had very volatile results with a very high variance as we had not a lot of data for this very specific case (only 43) but now since we have 243 results we should be able to observe better results.

# %%
# herding effect on 1-5star
result = matching_df.query('type == "HL"')[highest_diff].apply(lambda x: find_n_reviews(x, 5, review_books_df), 1)

# create 2 df based on the result of our functions with the 5 reviews as columns
H_in_HL_df = pd.DataFrame([x[0] for x in result])
L_in_HL_df = pd.DataFrame([x[1] for x in result])

# compute the interesting stats for each reviews
H_in_HL_stats = compute_stats_on_reviews_df(H_in_HL_df)
L_in_HL_stats = compute_stats_on_reviews_df(L_in_HL_df)

# plot the result in a nice plot
plot_stats_bar_plot('Average Rating following H/L first rating (only 5 and 1 star)',
                    H_in_HL_stats, light_green, 'H in HL', L_in_HL_stats, light_red, 'L in HL')

# %% [markdown]
# Interestingly enough, we see a much higher difference on the second review that seems to converge toward a similar value. It's also worth noting that the final value seems to be significantly lower than in the previous case. However we also observe that it still takes arround 3 to 4 review before coming back to a similar converging value.

# %% [markdown]
# To confirm our result and hypothesis we can now check the difference between what we have just above and what we get performing the same pipeline on the different groups (HH, HM..). In the HH case, we expect to have no herding effect at all, and converging results right from the beginning. Regarding the HM case, we would expect to see the same effect as above but this time lowered.

# %% [markdown]
# Let's once more confirm our theory on the HH category. This time on many more data as the HH category regroup no less than 1787 pairs of books this time.

# %%
# herding effect on HH
result = matching_df.query('type == "HH"').apply(lambda x: find_n_reviews(x, 5, review_books_df), 1)

# create 2 df based on the result of our functions with the 5 reviews as columns
H_in_HH_df = pd.DataFrame([x[0] for x in result])
Hstar_in_HH_df = pd.DataFrame([x[1] for x in result])

# compute the interesting stats for each reviews
H_in_HH_stats = compute_stats_on_reviews_df(H_in_HH_df)
Hstar_in_HH_stats = compute_stats_on_reviews_df(Hstar_in_HH_df)

plot_stats_bar_plot('Average Rating following H/H first rating',
                    H_in_HH_stats, light_green, 'H in HH', Hstar_in_HH_stats, strong_green, 'H* in HH')

# %% [markdown]
# And this is indeed a confirmation of our findings. We can clearly see here that when 2 books start with a high review, all the following reviews tends to be similar which confirm that the difference might be due to the first review being different. (herding effect)

# %% [markdown]
# #### Deeper Analysis of the left over categories from MS2 analysis
#
# In the smaller scale analysis, we were not able to study some groups such as LL and MM as the number value we had at our disposal was to small. Now that we have more data at hand, it could be interesting to study these groups as well. Studying MM and LL should confirm our hypothesis on the herding effect, while we would expect ML and HM to show slightly less impact of the herding effect as the difference between their first review would be smaller.
#
# This time again, one should be carefull with the results regarding the smaller group such as LL and MM should be as the number of data might be to small to draw significant conclusion.

# %% [markdown]
# #### confirmation of the herding effect on MM and LL

# %%
# herding effect on MM
result = matching_df.query('type == "MM"').apply(lambda x: find_n_reviews(x, 5, review_books_df), 1)

# create 2 df based on the result of our functions with the 5 reviews as columns
M_in_MM_df = pd.DataFrame([x[0] for x in result])
Mstar_in_MM_df = pd.DataFrame([x[1] for x in result])

# compute the interesting stats for each reviews
M_in_MM_stats = compute_stats_on_reviews_df(M_in_MM_df)
Mstar_in_MM_stats = compute_stats_on_reviews_df(Mstar_in_MM_df)

plot_stats_bar_plot('Average Rating following M/M first rating',
                    M_in_MM_stats, orange, 'M in MM', Mstar_in_MM_stats, orange, 'M* in MM')

# %%
# herding effect on LL
result = matching_df.query('type == "LL"').apply(lambda x: find_n_reviews(x, 5, review_books_df), 1)

# create 2 df based on the result of our functions with the 5 reviews as columns
L_in_LL_df = pd.DataFrame([x[0] for x in result])
Lstar_in_LL_df = pd.DataFrame([x[1] for x in result])

# compute the interesting stats for each reviews
L_in_LL_stats = compute_stats_on_reviews_df(L_in_LL_df)
Lstar_in_LL_stats = compute_stats_on_reviews_df(Lstar_in_LL_df)

plot_stats_bar_plot('Average Rating following L/L first rating',
                    L_in_LL_stats, light_red, 'L in LL', Lstar_in_LL_stats, strong_red, 'L* in LL')

# %% [markdown]
# Considering that MM and LL represent respectively only 128 and 182 pairs of data we observe a high variability in the results. However we can clearly see by taking off the noise coming from the low number of data that the rating after similar first rating is also similar (no herding effect). This is what we observe better and at a larger scale on the HH group just above.

# %% [markdown]
# #### confirmation of a smaller herding effect on HM and ML

# %%
# herding effect on HM
result = matching_df.query('type == "HM"').apply(lambda x: find_n_reviews(x, 5, review_books_df), 1)

# create 2 5reviews df based on the result of our functions
H_in_HM_df = pd.DataFrame([x[0] for x in result])
M_in_HM_df = pd.DataFrame([x[1] for x in result])

# compute the interesting stats for each reviews
H_in_HM_stats = compute_stats_on_reviews_df(H_in_HM_df)
M_in_HM_stats = compute_stats_on_reviews_df(M_in_HM_df)

plot_stats_bar_plot('Average Rating following H/M first rating',
                    H_in_HM_stats, light_green, 'H in HM', M_in_HM_stats, orange, 'M in HM')

# %% [markdown]
# We got interesting results here as we have almost 820 results falling into this HM group. We observe that the difference between first rating seems to be to small to lead to a strong herding effect as we could observe in the HL group. However we still see that the second review tends to be slightly lower before converging back toward a similar value.
#
# We could infer from this plot that a smaller difference in first review rating would lead to a smaller impact on the difference of the following ratings but it could also impact the length of the impact of the herding effect.

# %%
# herding effect on ML
result = matching_df.query('type == "ML"').apply(lambda x: find_n_reviews(x, 5, review_books_df), 1)

# create 2 5reviews df based on the result of our functions
M_in_ML_df = pd.DataFrame([x[0] for x in result])
L_in_ML_df = pd.DataFrame([x[1] for x in result])

# compute the interesting stats for each reviews
M_in_ML_stats = compute_stats_on_reviews_df(M_in_ML_df)
L_in_ML_stats = compute_stats_on_reviews_df(L_in_ML_df)

plot_stats_bar_plot('Average Rating following M/L first rating',
                    M_in_ML_stats, orange, 'M in ML', L_in_ML_stats, light_red, 'L in ML')

# %% [markdown]
# Here the results are more volatile as we have only arround 250 data. That being said, and the first review rating difference being higher in this group (compared to HM), we can still observe a nice herding effect on the few following ratings. Once again the effect is lowered compared to what we could observe on the HL or the extreme HL group for example.

# %% [markdown]
# To conclude on this part it seems that our hypothesis of herding effect is validated once again on our scaled dataset. We confirmed our hypothesis strongly on the HL and extreme HL categories and slightly on the HM and ML categories. Observing the HH, MM and LL group helped us to validate our theory on independant pairs of books.
#
# We can now, tell that the first review as an influence on the following reviews weigthed by the difference in the rate of the first review. We also observed that after only a few review (2 to 3 reviews) the herding effect seems to fade off and both rating converge toward a similar value.
#
# Scaling up the data in this milestone also helped to understand and confirm some new phenomon such as the importance of the magnitude of the difference between the first review in observing the herding effect.
#
# We are now going to check if the herding effect is really fading and converging in the next part focused on the long term effect of herding.

# %% [markdown]
# #### long term effect of herding on the scaled dataset

# %% [markdown]
# To assess the long term effect of herding, we will look at the pair of books with more than 10 reviews and compute the mean of all the reviews after that as well as it's 95% confidence interval. Then we will will compare our result for the different group we have at hand.

# %%
# find the average last reviews for each HH pairs
result = matching_df.query('type == "HH"').apply(lambda x: mean_more_n_reviews(x, 10, review_books_df), 1)
H_in_HH_df = pd.DataFrame([x[0] for x in result]).dropna().reset_index().drop(['index'], axis=1)

# find the average last reviews for each MM pairs
result = matching_df.query('type == "MM"').apply(lambda x: mean_more_n_reviews(x, 10, review_books_df), 1)
M_in_MM_df = pd.DataFrame([x[0] for x in result]).dropna().reset_index().drop(['index'], axis=1)

# find the average last reviews for each LL pairs
result = matching_df.query('type == "LL"').apply(lambda x: mean_more_n_reviews(x, 10, review_books_df), 1)
L_in_LL_df = pd.DataFrame([x[0] for x in result]).dropna().reset_index().drop(['index'], axis=1)

# find the average last reviews for each HL pairs
result = matching_df.query('type == "HL"').apply(lambda x: mean_more_n_reviews(x, 10, review_books_df), 1)
H_in_HL_df = pd.DataFrame([x[0] for x in result]).dropna().reset_index().drop(['index'], axis=1)
L_in_HL_df = pd.DataFrame([x[1] for x in result]).dropna().reset_index().drop(['index'], axis=1)

# find the average last reviews for each HM pairs
result = matching_df.query('type == "HM"').apply(lambda x: mean_more_n_reviews(x, 10, review_books_df), 1)
H_in_HM_df = pd.DataFrame([x[0] for x in result]).dropna().reset_index().drop(['index'], axis=1)
M_in_HM_df = pd.DataFrame([x[1] for x in result]).dropna().reset_index().drop(['index'], axis=1)

# find the average last reviews for each ML pairs
result = matching_df.query('type == "ML"').apply(lambda x: mean_more_n_reviews(x, 10, review_books_df), 1)
M_in_ML_df = pd.DataFrame([x[0] for x in result]).dropna().reset_index().drop(['index'], axis=1)
L_in_ML_df = pd.DataFrame([x[1] for x in result]).dropna().reset_index().drop(['index'], axis=1)



# compute mean and error for each HH books
H_in_HH_mean = np.mean(H_in_HH_df['mean'])
H_in_HH_error = error_from_interval(
    st.t.interval(0.95, len(H_in_HH_df)-1, loc=H_in_HH_mean, scale=st.sem(H_in_HH_df['mean'])))

# compute mean and error for each MM books
M_in_MM_mean = np.mean(M_in_MM_df['mean'])
M_in_MM_error = error_from_interval(
    st.t.interval(0.95, len(M_in_MM_df)-1, loc=M_in_MM_mean, scale=st.sem(M_in_MM_df['mean'])))

# compute mean and error for each LL books
L_in_LL_mean = np.mean(L_in_LL_df['mean'])
L_in_LL_error = error_from_interval(
    st.t.interval(0.95, len(L_in_LL_df)-1, loc=L_in_LL_mean, scale=st.sem(L_in_LL_df['mean'])))

# compute mean and error for each HL books
H_in_HL_mean = np.mean(H_in_HL_df['mean'])
H_in_HL_error = error_from_interval(
    st.t.interval(0.95, len(H_in_HL_df)-1, loc=H_in_HL_mean, scale=st.sem(H_in_HL_df['mean'])))

L_in_HL_mean = np.mean(L_in_HL_df['mean'])
L_in_HL_error = error_from_interval(
    st.t.interval(0.95, len(L_in_HL_df)-1, loc=L_in_HL_mean, scale=st.sem(L_in_HL_df['mean'])))

# compute mean and error for each HM books
H_in_HM_mean = np.mean(H_in_HM_df['mean'])
H_in_HM_error = error_from_interval(
    st.t.interval(0.95, len(H_in_HM_df)-1, loc=H_in_HM_mean, scale=st.sem(H_in_HM_df['mean'])))

M_in_HM_mean = np.mean(M_in_HM_df['mean'])
M_in_HM_error = error_from_interval(
    st.t.interval(0.95, len(M_in_HM_df)-1, loc=M_in_HM_mean, scale=st.sem(M_in_HM_df['mean'])))

# compute mean and error for each ML books
M_in_ML_mean = np.mean(M_in_ML_df['mean'])
M_in_ML_error = error_from_interval(
    st.t.interval(0.95, len(M_in_ML_df)-1, loc=M_in_ML_mean, scale=st.sem(M_in_ML_df['mean'])))

L_in_ML_mean = np.mean(L_in_ML_df['mean'])
L_in_ML_error = error_from_interval(
    st.t.interval(0.95, len(L_in_ML_df)-1, loc=L_in_ML_mean, scale=st.sem(L_in_ML_df['mean'])))

# finally plot our results
plot_lastreviews_means_and_errors_scaled(H_in_HH_mean, H_in_HH_error, M_in_MM_mean,
                                         M_in_MM_error, L_in_LL_mean, L_in_LL_error,
                                         H_in_HL_mean, H_in_HL_error, L_in_HL_mean,
                                         L_in_HL_error, H_in_HM_mean, H_in_HM_error,
                                         M_in_HM_mean, M_in_HM_error, M_in_ML_mean,
                                         M_in_ML_error, L_in_ML_mean, L_in_ML_error)

# %% [markdown]
# First thing to observe here is that: every time the first review differ (HL, HM or ML), we can observe a lower average on the lower first review. This would confirm that the herding effect through first review of a book tends to impact the whole average rating of the following reviews even after more than 10 reviews.
#
# We also observed quiet obviously that HH and MM tends to have a higher average than their counterpart HL/HM or ML.

# %% [markdown]
# We can draw a similar conclusion here than for the previous milestone: even if on the previous analysis of the first 5 ratings it seemed that the rating was converging after a few reviews. We observe by deeply analysing the 10-th and above reviews that a first negative review still impact the long term rating of the product in some way. Confirming our results on more groups and with more data is once again very gratifying and confirm that our theory from previous milestone are validated.

# %% [markdown]
# #### Limitation of this analysis
#
# Even though we had good results in favor of our hypothesis on herding effect on the books review on Amazon for the first few reviews following, we are aware that our analysis has some limitating factors. For example, when we matched two very similar books together, we considered that they were completely identical. However some external factors may bias our analysis such as the edition, the price of the book and the type of cover as well as may other considerations that could affect the rating of the review such as the date of the review and publication of the product...

# %% [markdown]
# # Connection to how amazon displays reviews

# %% [markdown]
# To us it seemed important to look at how does amazon actually manages their reviews, because it seemed counter-intuitive that they would display all the reviews of the product all the time as those can be quite numerous and therefore unpractical to display.

# %% [markdown]
# By exploring some examples it seems like the reviews are not all displayed indeed amazon chooses to only display "Top Customer reviews". (note that the following study doesn't attempt to give an extensive comprehension of how reviews are displayed but more trying to identify a pattern using a very empirical method).
#
# Here are some examples of books with low number of reviews :
# * 2 reviews (the lowest we could find): [The spanish rose](https://www.amazon.com/Spanish-Rose-Shirlee-Busbee/dp/2724237145/ref=sr_1_1200?s=books&ie=UTF8&qid=1513327548&sr=1-1200&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011)
# * 3 reviews: [Reussir le Delf A2](https://www.amazon.com/Reussir-Delf-A2-Livre-French/dp/0320083675/ref=sr_1_1117?s=books&ie=UTF8&qid=1513327906&sr=1-1117&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011)
# * 4 reviews: [Je m'en vais](https://www.amazon.com/men-vais-Relié-Echenoz-Jean/dp/B000GQYSRE/ref=sr_1_865?s=books&ie=UTF8&qid=1513327959&sr=1-865&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011)
# * 5 reviews: [Les enfants du capitain Grant II](https://www.amazon.com/enfants-capitaine-grant-II/dp/B010QHIJT0/ref=sr_1_745?s=books&ie=UTF8&qid=1513327990&sr=1-745&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011)
# * 7 reviews: [Les enfants terribles](https://www.amazon.com/Enfants-terribles-Cocteau-Jean/dp/B00E9WMZSU/ref=sr_1_625?s=books&ie=UTF8&qid=1513328018&sr=1-625&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011)
#
# By examining the reviews of those books, the only pattern that we can observe is the fact that verified reviews are always first. But then, there is no real similarities between the different books. The date, helpfulness, length of the review, or grade do not seem to have anything to do with the order in which the reviews are displayed

# %% [markdown]
# If we move toward books with more reviews, it seems like the maximum number of displayed reviews is 8:
# * 10 reviews : [Contes du lundi](https://www.amazon.com/Contes-du-Lundi-Alphonse-Daudet/dp/B01F621CY4/ref=sr_1_506?s=books&ie=UTF8&qid=1513329341&sr=1-506&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011)

# %% [markdown]
# But in fact, this observation isn't always true. ([here](https://www.amazon.com/Mademoiselle-Maupin-Nouvelle-édition-French/dp/2014039488/ref=sr_1_577?s=books&ie=UTF8&qid=1513329486&sr=1-577&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011) there are only 6 reviews that are displayed while there exists 9 reviews). Nevertheless, we can make the hypothesis that amazon displays reviews depending on their length, it doesn't want to have more than a certain space of the product page that contains reviews, if reviews are short it will display up to *8 reviews*.

# %% [markdown]
# ## Computation of average grading

# %% [markdown]
# There is one thing that we didn't take into consideration and that could explain the fact that the review average that we considered didn't correlate as expected with the sales rank. Indeed amazon's average review grade isn't computed directly from the raw data but is based on a machine learned formula as displayed here in the disclaimer (from this [product page](https://www.amazon.com/Shakespeare-French-Hamlet-Othello-Macbeth/dp/B00P022SWQ/ref=sr_1_13?s=books&ie=UTF8&qid=1513329797&sr=1-13&keywords=livre&refinements=p_n_feature_nine_browse-bin%3A3291438011%2Cp_72%3A1250224011)):

# %%
from IPython.display import Image
Image(filename='assets/disclaimer.png',width=550)

# %% [markdown]
# And indeed if we look at the average we would obtain using a mean of all ratings we would obtain :

# %%
(2732*5+684*4+304*3+2*143+1*249)/4112
# Out:
# 4.339250972762646

# %% [markdown]
# the difference isn't overwhelming given the very large number of reviews. Nevertheless, on [an example](https://www.amazon.com/Enfants-terribles-Cocteau-Jean/product-reviews/B00E9WMZSU/ref=cm_cr_arp_d_viewopt_sr?ie=UTF8&filterByStar=one_star&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar) with less reviews and a repartition of verified reviews that are different :
# * $4$ 5-star reviews (with only 1 verified)
# * $1$ 4-star review
# * $2$ 1-star reviews (with only 1 verified)
# The displayed average is $3.3$. With a simple mean we would expect to have :

# %%
(5*4+4*1+1*2)/7
# Out:
# 3.7142857142857144

# %% [markdown]
# We can see that the displayed average gives a lower score than ours, this could be explained by the fact that it gives a lot of importance to the 1-star verified reviews.

# %% [markdown]
# ## Incentivized reviews

# %% [markdown]
# While amazon is opposed to paid reviews and has in 2016 decided to sue users that bought fake reviews (as seen in [techcrunch](https://techcrunch.com/2016/06/01/amazon-sues-sellers-for-buying-fake-reviews/)), it does allow sellers to offer discount (even up to 100%) to reviewers in exchange for an honest review. This as been managed partly by amazon through the [vine program](https://www.amazon.com/gp/vine/help) that proposes trusted reviewers (based on their reviewer ranks) to receive free products to review them.

# %% [markdown]
# Eventhough these reviews are supposed to be unbiased, a study by [reviewmeta](https://reviewmeta.com/blog/analysis-of-7-million-amazon-reviews-customers-who-receive-free-or-discounted-item-much-more-likely-to-write-positive-review/) shows that they tend to be more positive than regular reviews. Nevertheless, since their article, amazon has decided [to forbid incentivized](https://blog.aboutamazon.com/innovation/update-on-customer-reviews) reviews unless they are part of the Vine program.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From this quick analysis we can see that amazon is very careful about its reviews and take all the precaution it can to protect the trustfulness of such reviews. Even though we couldn't find what reviews it displayed exactly, we can see that the fact that the Herding Effect disappears quickly (within 3 reviews) is mostly due to the fact that the average review grade is always displayed and gets corrected quickly when new reviews come in.
#
# If we take the example of the herding effect in the case of ```HL``` compared to ```HM``` then we can observe interesting things.
# Think about the case of a first review belonging to ```L``` in the ```HL``` case. Then one can see that the 2nd review is on average higher than 3.5 and therefore belongs to ```M```. Then the case is somehow close to when the 2nd review comes after a ```M``` review in the ```HM``` case. In such case, it takes on average one review to recover from the Herding effect which could explain why in the ```HL``` case it takes on average 2 reviews to recover.
